# %% [markdown]
# # Single versus Dual domain

# %% [markdown]
# ## Single domain

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute the input file
raw_data = ross.execute(print_output = False)
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# Estimated completion in 17.0 seconds by 2021-10-17 19:55:16.466725 local time.
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 43.4       1.237e-14   2.498e-13  2.761e-10    1.551e-6    1.586e-6
# 47.4        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 51.3        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 55.2        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 59.2        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 63.1        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 67.1        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 71.0        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 75.0        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
# 78.9        6.558e-9    1.324e-7   1.464e-4      0.8222      0.8408
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 43.4          2.193e-7    4.254e-8   1.710e-8    1.504e-7   2.104e-10
# 47.4            0.1153     0.02158   9.065e-3     0.07974    1.115e-4
# 51.3            0.1153     0.02158   9.065e-3     0.07974    1.115e-4
# 55.2            0.1153     0.02158   9.065e-3     0.07974    1.115e-4
# 59.2            0.1153     0.02158   9.065e-3     0.07974    1.115e-4
# 63.1            0.1153     0.02157   9.065e-3     0.07974    1.115e-4
# 67.1            0.1153     0.02157   9.065e-3     0.07974    1.115e-4
# 71.0            0.1153     0.02157   9.065e-3     0.07974    1.115e-4
# 75.0            0.1153     0.02157   9.065e-3     0.07974    1.115e-4
# 78.9            0.1153     0.02157   9.065e-3     0.07974    1.115e-4
#
#          Ba(mol/kgw) Li(mol/kgw)
# Time (s)
# 43.4       1.779e-13   7.295e-11
# 47.4        9.431e-8    3.868e-5
# 51.3        9.431e-8    3.868e-5
# 55.2        9.431e-8    3.868e-5
# 59.2        9.431e-8    3.868e-5
# 63.1        9.431e-8    3.868e-5
# 67.1        9.431e-8    3.868e-5
# 71.0        9.431e-8    3.868e-5
# 75.0        9.431e-8    3.868e-5
# 78.9        9.431e-8    3.868e-5

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# Estimated completion in 38.0 seconds by 2021-10-17 19:55:40.179653 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 0.127                  0.00
# 0.212                  0.00
# 0.296                  0.00
# 0.381                  0.00
# 0.466                 0.439
# 0.550                  8.21
# 0.635                  7.98
# 0.720                  7.71
# 0.804                  7.45
# 0.889                  7.19

# %% [markdown]
# ## Dual domain

# %% [markdown]
# ## Immobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'immobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute the input file
raw_data = ross.execute(print_output = False)
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# Estimated completion in 17.0 seconds by 2021-10-17 19:55:25.076618 local time.
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 75.0       1.665e-16   3.362e-15  3.716e-12    2.087e-8    2.135e-8
# 78.9       3.801e-16   7.675e-15  8.484e-12    4.765e-8    4.873e-8
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 75.0          2.956e-9   5.772e-10  2.301e-10    2.024e-9   2.832e-12
# 78.9          6.749e-9    1.318e-9  5.254e-10    4.621e-9   6.464e-12
#
#          Ba(mol/kgw) Li(mol/kgw)
# Time (s)
# 75.0       2.394e-15   9.819e-13
# 78.9       5.466e-15   2.242e-12

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'immobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# Estimated completion in 38.0 seconds by 2021-10-17 19:55:50.389932 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 0.0423                 0.00
# 0.127                 0.829
# 0.212                  0.00
# 0.296                  0.00
# 0.381                  0.00
# 0.466                  0.00
# 0.550                  0.00
# 0.635                  0.00
# 0.720                  0.00
# 0.804                  0.00
# 0.889                  0.00

# %% [markdown]
# ## Mobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'mobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute the input file
raw_data = ross.execute(print_output = False)
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# Estimated completion in 17.0 seconds by 2021-10-17 19:55:40.151205 local time.
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 75.0       1.660e-16   3.352e-15  3.705e-12    2.081e-8    2.128e-8
# 78.9       3.789e-16   7.652e-15  8.459e-12    4.751e-8    4.858e-8
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 75.0          2.947e-9   5.755e-10  2.294e-10    2.018e-9   2.823e-12
# 78.9          6.728e-9    1.314e-9  5.238e-10    4.608e-9   6.445e-12
#
#          Ba(mol/kgw) Li(mol/kgw)
# Time (s)
# 75.0       2.387e-15   9.789e-13
# 78.9       5.450e-15   2.235e-12

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'mobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# Estimated completion in 38.0 seconds by 2021-10-17 19:56:05.499703 local time.
# No scaling occurred.
# None
