# %% [markdown]
# # Single versus Dual domain

# %% [markdown]
# ## Single domain

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 1.70E1 seconds by 2021-11-25 23:10:28.513908 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 4 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 4.34E1     1.237E-14   2.497E-13  2.761E-10    1.551E-6    1.586E-6
# 4.74E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 5.13E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 5.52E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 5.92E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 6.31E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 6.71E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 7.10E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 7.50E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 7.89E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 4.34E1        2.193E-7    4.255E-8   1.709E-8    1.504E-7   2.103E-10
# 4.74E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.13E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.52E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.92E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 6.31E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 6.71E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.10E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.50E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.89E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
#
#          Ba(mol/kgw) Li(mol/kgw) Zn(mol/kgw) Ni(mol/kgw) Cu(mol/kgw)  \
# Time (s)
# 4.34E1     1.779E-13   7.294E-11     0.000E0     0.000E0     0.000E0
# 4.74E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 5.13E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 5.52E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 5.92E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 6.31E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 6.71E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 7.10E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 7.50E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
# 7.89E1      9.429E-8    3.867E-5     0.000E0     0.000E0     0.000E0
#
#          Cd(mol/kgw) Co(mol/kgw) Pb(mol/kgw)
# Time (s)
# 4.34E1       0.000E0     0.000E0     0.000E0
# 4.74E1       0.000E0     0.000E0     0.000E0
# 5.13E1       0.000E0     0.000E0     0.000E0
# 5.52E1       0.000E0     0.000E0     0.000E0
# 5.92E1       0.000E0     0.000E0     0.000E0
# 6.31E1       0.000E0     0.000E0     0.000E0
# 6.71E1       0.000E0     0.000E0     0.000E0
# 7.10E1       0.000E0     0.000E0     0.000E0
# 7.50E1       0.000E0     0.000E0     0.000E0
# 7.89E1       0.000E0     0.000E0     0.000E0

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection,)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:05:16.050380 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             4.39E-1
# 5.50E-1              8.21E0
# 6.35E-1              7.98E0
# 7.20E-1              7.71E0
# 8.04E-1              7.45E0
# 8.89E-1              7.19E0

# %% [markdown]
# ## Dual domain

# %% [markdown]
# ## Immobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'immobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 1.70E1 seconds by 2021-11-25 23:18:45.811048 local time.
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-16-2abbd64f7fae> in <module>
#      23
#      24 # execute the input file
# ---> 25 raw_data = ross.execute()
#      26 brine_data = ross.process_selected_output()
#      27 display(brine_data)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in execute(self, simulated_to_real_time)
#     815
#     816         # execute the simulation
# --> 817         main(self.input_file)
#     818         if self.verbose:
#     819             print('run_time (s):', self.variables['run_time (s)'])
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in main(input_file)
#     791                 return phreeqc, conc, timeit.default_timer() - start
#     792
# --> 793             phreeqc, conc, run_time = measure_time(run, input_file)
#     794
#     795             # export the simulation results
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in measure_time(func, *args, **kwargs)
#     788             def measure_time(func, *args, **kwargs):
#     789                 start = timeit.default_timer()
# --> 790                 phreeqc, conc = func(*args, **kwargs)
#     791                 return phreeqc, conc, timeit.default_timer() - start
#     792
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in run(input_file, first)
#     770
#     771             # run the simulation
# --> 772             phreeqc.run_string(input_file)
#     773
#     774             # define the conc dictionary
#
# C:\Program Files (x86)\Anaconda3\lib\site-packages\win32com\client\dynamic.py in RunString(self, input)
#
# com_error: (-2147352567, 'Exception occurred.', (0, 'IPhreeqcCOM.Object.4', 'ERROR: Negative concentration in solution 14. Stopping calculation.\n', None, 0, -2147352567), None)

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'immobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:09:14.604601 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1             8.29E-1
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.23E-2              0.00E0
# 4.66E-1              0.00E0
# 5.50E-1              0.00E0
# 6.35E-1              0.00E0
# 7.20E-1              0.00E0
# 8.04E-1              0.00E0
# 8.89E-1              0.00E0

# %% [markdown]
# ## Mobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'mobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 1.70E1 seconds by 2021-10-27 22:09:04.747781 local time.
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 7.50E1     1.660E-16   3.352E-15  3.705E-12    2.081E-8    2.128E-8
# 7.89E1     3.789E-16   7.652E-15  8.459E-12    4.751E-8    4.858E-8
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 7.50E1        2.947E-9   5.755E-10  2.294E-10    2.018E-9   2.823E-12
# 7.89E1        6.728E-9    1.314E-9  5.238E-10    4.608E-9   6.445E-12
#
#          Ba(mol/kgw) Li(mol/kgw)
# Time (s)
# 7.50E1     2.387E-15   9.789E-13
# 7.89E1     5.450E-15   2.235E-12

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'mobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:09:30.431135 local time.
# No scaling occurred.
# None
