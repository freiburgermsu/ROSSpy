# %% [markdown]
# # Execute the wastewater simulation

# %%
# execute the ROSSpy simulation
# %run ../../../../rosspy/ro.py

# initial parameters
database_selection = 'pitzer'
simulation_perspective = 'all_distance'
simulation_time = 200
simulation_name = 'Lee_et_al_wastewater'

# Define the feed conditions
water_selection = 'wastewater'
water_characteristics = {
    'element': {
        'Li': {
            'concentration (ppm)': 0.04
        },
        'Na': {
            'concentration (ppm)': 161
        },
        'Mg': {
            'concentration (ppm)': 3.5
        },
        'Ca': {
            'concentration (ppm)': 1303
        }, 
        'K': {
            'concentration (ppm)': 37
        },
        'Mn': {
            'concentration (ppm)': 0.09
        }, 
        'Fe': {
            'concentration (ppm)': 9.8
        }, 
        'Co': {
            'concentration (ppm)': 0.13
        }, 
        'Cu': {
            'concentration (ppm)': 0.03
        },
    },
    'temperature': {
        'value': 20
    },
    'Alkalinity': {
        'value': 500
    },
    'pH': {
        'value': 7.5
    },
}

# create the input file
ross = ROSSPkg(database_selection, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection, water_characteristics)
ross.execute(simulation_name, export_format="eps")
# Out:
# --> The ['Co', 'Cu'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-11-24 11:31:55.658964 local time.
# run_time (s): 3.8931789000000006
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#                Calcite (g/m^2)
# Distance ($m$)
# 4.23E-2                8.760E1
# 1.27E-1               3.200E-1
# 2.12E-1               3.140E-1
# 2.96E-1               3.080E-1
# 3.81E-1               3.020E-1
# 4.66E-1               2.960E-1
# 5.50E-1               2.900E-1
# 6.35E-1               2.840E-1
# 7.20E-1               2.790E-1
# 8.04E-1               2.730E-1
# 8.89E-1               2.670E-1
# 9.74E-1               2.610E-1
