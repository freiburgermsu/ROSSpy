# %%
# import the parsing script
# %run ../processing_databases.py

# conduct the database reconfiguration
erroneous_databases = []
for database in glob('../databases/*.dat'):
    elements, minerals = database_parsing(database)
    database_json_creation(database, elements, minerals)
#     except:
#         erroneous_databases.append(database)
#         print(f'ERROR: {database}')

print(erroneous_databases)
problem_databases = ['./databases\\frezchem.dat', './databases\\iso.dat', './databases\\llnl.dat', './databases\\minteq.dat', './databases\\minteq.v4.dat', './databases\\sit.dat', './databases\\Tipping_Hurley.dat', './databases\\wateq4f.dat']
# Out:
# ../databases\Amm.dat
#              0       1     2              3        4
# 1            H      H+  -1.0              H    1.008
# 2         H(0)      H2     0              H     None
# 3         H(1)      H+  -1.0              0     None
# 4            E      e-     0            0.0        0
# 5            O     H2O     0              O     16.0
# 6         O(0)      O2     0              O     None
# 7        O(-2)     H2O     0              0     None
# 8           Ca    Ca+2     0             Ca    40.08
# 9           Mg    Mg+2     0             Mg   24.312
# 10          Na     Na+     0             Na  22.9898
# 11           K      K+     0              K   39.102
# 12          Fe    Fe+2     0             Fe   55.847
# 13      Fe(+2)    Fe+2     0             Fe     None
# 14      Fe(+3)    Fe+3  -2.0             Fe     None
# 15          Mn    Mn+2     0             Mn   54.938
# 16      Mn(+2)    Mn+2     0             Mn     None
# 17      Mn(+3)    Mn+3     0             Mn     None
# 18          Al    Al+3     0             Al  26.9815
# 19          Ba    Ba+2     0             Ba   137.34
# 20          Sr    Sr+2     0             Sr    87.62
# 21          Si  H4SiO4     0           SiO2  28.0843
# 22          Cl     Cl-     0             Cl   35.453
# 23           C   CO3-2   2.0           HCO3  12.0111
# 24       C(+4)   CO3-2   2.0           HCO3     None
# 25       C(-4)     CH4     0            CH4     None
# 26  Alkalinity   CO3-2   1.0  Ca0.5(CO3)0.5    50.05
# 27           S   SO4-2     0            SO4   32.064
# 28        S(6)   SO4-2     0            SO4     None
# 29       S(-2)     HS-   1.0              S     None
# 30           N    NO3-     0              N  14.0067
# 31       N(+5)    NO3-     0            NO3     None
# 32       N(+3)    NO2-     0            NO2     None
# 33        N(0)      N2     0              N     None
# 34         Amm   AmmH+     0           AmmH   17.031
# 35           B   H3BO3     0              B    10.81
# 36           P   PO4-3   2.0              P  30.9738
# 37           F      F-     0              F  18.9984
# 38          Li     Li+     0             Li    6.939
# 39          Br     Br-     0             Br   79.904
# 40          Zn    Zn+2     0             Zn    65.37
# 41          Cd    Cd+2     0             Cd    112.4
# 42          Pb    Pb+2     0             Pb   207.19
# 43          Cu    Cu+2     0             Cu   63.546
# 44      Cu(+2)    Cu+2     0             Cu     None
# 45      Cu(+1)    Cu+1     0             Cu     None
# 46          Sg    H2Sg   1.0           H2Sg    34.08
#       elements species   alk    gfw_formula element_gfw
# 1            H      H+  -1.0              H       1.008
# 2         H(0)      H2     0              H        None
# 3         H(1)      H+  -1.0              0        None
# 4            E      e-     0            0.0           0
# 5            O     H2O     0              O        16.0
# 6         O(0)      O2     0              O        None
# 7        O(-2)     H2O     0              0        None
# 8           Ca    Ca+2     0             Ca       40.08
# 9           Mg    Mg+2     0             Mg      24.312
# 10          Na     Na+     0             Na     22.9898
# 11           K      K+     0              K      39.102
# 12          Fe    Fe+2     0             Fe      55.847
# 13      Fe(+2)    Fe+2     0             Fe        None
# 14      Fe(+3)    Fe+3  -2.0             Fe        None
# 15          Mn    Mn+2     0             Mn      54.938
# 16      Mn(+2)    Mn+2     0             Mn        None
# 17      Mn(+3)    Mn+3     0             Mn        None
# 18          Al    Al+3     0             Al     26.9815
# 19          Ba    Ba+2     0             Ba      137.34
# 20          Sr    Sr+2     0             Sr       87.62
# 21          Si  H4SiO4     0           SiO2     28.0843
# 22          Cl     Cl-     0             Cl      35.453
# 23           C   CO3-2   2.0           HCO3     12.0111
# 24       C(+4)   CO3-2   2.0           HCO3        None
# 25       C(-4)     CH4     0            CH4        None
# 26  Alkalinity   CO3-2   1.0  Ca0.5(CO3)0.5       50.05
# 27           S   SO4-2     0            SO4      32.064
# 28        S(6)   SO4-2     0            SO4        None
# 29       S(-2)     HS-   1.0              S        None
# 30           N    NO3-     0              N     14.0067
# 31       N(+5)    NO3-     0            NO3        None
# 32       N(+3)    NO2-     0            NO2        None
# 33        N(0)      N2     0              N        None
# 34         Amm   AmmH+     0           AmmH      17.031
# 35           B   H3BO3     0              B       10.81
# 36           P   PO4-3   2.0              P     30.9738
# 37           F      F-     0              F     18.9984
# 38          Li     Li+     0             Li       6.939
# 39          Br     Br-     0             Br      79.904
# 40          Zn    Zn+2     0             Zn       65.37
# 41          Cd    Cd+2     0             Cd       112.4
# 42          Pb    Pb+2     0             Pb      207.19
# 43          Cu    Cu+2     0             Cu      63.546
# 44      Cu(+2)    Cu+2     0             Cu        None
# 45      Cu(+1)    Cu+1     0             Cu        None
# 46          Sg    H2Sg   1.0           H2Sg       34.08
# 0           phases                       formula
# 1          Calcite                         CaCO3
# 2        Aragonite                         CaCO3
# 3         Dolomite                    CaMg(CO3)2
# 4         Siderite                         FeCO3
# 5    Rhodochrosite                         MnCO3
# 6     Strontianite                         SrCO3
# 7        Witherite                         BaCO3
# 8           Gypsum                    CaSO4:2H2O
# 9        Anhydrite                         CaSO4
# 10       Celestite                         SrSO4
# 11          Barite                         BaSO4
# 12  Hydroxyapatite                   Ca5(PO4)3OH
# 13        Fluorite                          CaF2
# 14      Chalcedony                          SiO2
# 15          Quartz                          SiO2
# 16        Gibbsite                       Al(OH)3
# 17       Kaolinite                 Al2Si2O5(OH)4
# 18          Albite                     NaAlSi3O8
# 19       Anorthite                    CaAl2Si2O8
# 20            Talc                Mg3Si4O10(OH)2
# 21          Illite  K0.6Mg0.25Al2.3Si3.5O10(OH)2
# 22      Chrysotile                 Mg3Si2O5(OH)4
# 23       Sepiolite             Mg2Si3O7.5OH:3H2O
# 24        Hematite                         Fe2O3
# 25        Goethite                         FeOOH
# 26          Pyrite                          FeS2
# 27     Mackinawite                           FeS
# 28          Sulfur                             S
# 29       Vivianite                Fe3(PO4)2:8H2O
# 30     Hausmannite                         Mn3O4
# 31       Manganite                         MnOOH
# 32     Pyrochroite                       Mn(OH)2
# 33          Halite                          NaCl
# 34         Sylvite                           KCl
# 35     Melanterite                    FeSO4:7H2O
# 36         Alunite               KAl3(SO4)2(OH)6
# 37     Smithsonite                         ZnCO3
# 38      Sphalerite                           ZnS
# 39       Willemite                       Zn2SiO4
# 40         Otavite                         CdCO3
# 41           CdSiO                        CdSiO3
# 42            CdSO                         CdSO4
# 43       Cerussite                         PbCO3
# 44       Anglesite                         PbSO4
#
#
# Calcite CaCO3
#  =============
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 52.0887
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 100.0869
# ch_number 4
# character 3
# Calcite mass: 100.0869
#
#
# Aragonite CaCO3
#  ===============
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 52.0887
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 100.0869
# ch_number 4
# character 3
# Aragonite mass: 100.0869
#
#
# Dolomite CaMg(CO3)2
#  ===================
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character M
#
#  Mg
# elemental_mass1 24.305
# stoich1 1
# mass1 24.305
# mass 64.38300000000001
# ch_number 3
# character g
# mass 64.38300000000001
# ch_number 4
# character (
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# group_mass 60.0089
# group_stoich 2.0
# 4
# mass 184.4008
# ch_number 5
# character C
# mass 184.4008
# ch_number 6
# character O
# mass 184.4008
# ch_number 7
# character 3
# mass 184.4008
# ch_number 8
# character )
# mass 184.4008
# ch_number 9
# character 2
# Dolomite mass: 220.43136
#
#
# Siderite FeCO3
#  ==============
#
# mass 0
# ch_number 0
# character F
#
#  Fe
# elemental_mass1 55.845
# stoich1 1
# mass1 55.845
# mass 55.845
# ch_number 1
# character e
# mass 55.845
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 67.8557
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 115.8539
# ch_number 4
# character 3
# Siderite mass: 115.8539
#
#
# Rhodochrosite MnCO3
#  ===================
#
# mass 0
# ch_number 0
# character M
#
#  Mn
# elemental_mass1 54.938049
# stoich1 1
# mass1 54.938049
# mass 54.938049
# ch_number 1
# character n
# mass 54.938049
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 66.94874899999999
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 114.94694899999999
# ch_number 4
# character 3
# Rhodochrosite mass: 114.94694899999999
#
#
# Strontianite SrCO3
#  ==================
#
# mass 0
# ch_number 0
# character S
#
#  Sr
# elemental_mass1 87.62
# stoich1 1
# mass1 87.62
# mass 87.62
# ch_number 1
# character r
# mass 87.62
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 99.6307
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 147.6289
# ch_number 4
# character 3
# Strontianite mass: 147.6289
#
#
# Witherite BaCO3
#  ===============
#
# mass 0
# ch_number 0
# character B
#
#  Ba
# elemental_mass1 137.327
# stoich1 1
# mass1 137.327
# mass 137.327
# ch_number 1
# character a
# mass 137.327
# ch_number 2
# character C
#
#  C
# elemental_mass3 12.0107
# stoich3 1
# mass3 12.0107
# mass 149.33769999999998
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 3.0
# mass2 47.9982
# mass 197.33589999999998
# ch_number 4
# character 3
# Witherite mass: 197.33589999999998
#
#
# Gypsum CaSO4:2H2O
#  =================
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character S
#
#  S
# elemental_mass3 32.065
# stoich3 1
# mass3 32.065
# mass 72.143
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 4.0
# mass2 63.9976
# mass 136.1406
# ch_number 4
# character 4
# mass 136.1406
# ch_number 5
# character :
# mass 136.1406
# ch_number 6
# character 2
# mass 172.17116000000001
# ch_number 7
# character H
# mass 172.17116000000001
# ch_number 8
# character 2
# mass 172.17116000000001
# ch_number 9
# character O
# Gypsum mass: 172.17116000000001
#
#
# Anhydrite CaSO4
#  ===============
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character S
#
#  S
# elemental_mass3 32.065
# stoich3 1
# mass3 32.065
# mass 72.143
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 4.0
# mass2 63.9976
# mass 136.1406
# ch_number 4
# character 4
# Anhydrite mass: 136.1406
#
#
# Celestite SrSO4
#  ===============
#
# mass 0
# ch_number 0
# character S
#
#  Sr
# elemental_mass1 87.62
# stoich1 1
# mass1 87.62
# mass 87.62
# ch_number 1
# character r
# mass 87.62
# ch_number 2
# character S
#
#  S
# elemental_mass3 32.065
# stoich3 1
# mass3 32.065
# mass 119.685
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 4.0
# mass2 63.9976
# mass 183.6826
# ch_number 4
# character 4
# Celestite mass: 183.6826
#
#
# Barite BaSO4
#  ============
#
# mass 0
# ch_number 0
# character B
#
#  Ba
# elemental_mass1 137.327
# stoich1 1
# mass1 137.327
# mass 137.327
# ch_number 1
# character a
# mass 137.327
# ch_number 2
# character S
#
#  S
# elemental_mass3 32.065
# stoich3 1
# mass3 32.065
# mass 169.392
# ch_number 3
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 4.0
# mass2 63.9976
# mass 233.3896
# ch_number 4
# character 4
# Barite mass: 233.3896
#
#
# Hydroxyapatite Ca5(PO4)3OH
#  ==========================
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 5.0
# mass1 200.39000000000001
# mass 200.39000000000001
# ch_number 1
# character a
# mass 200.39000000000001
# ch_number 2
# character 5
# mass 200.39000000000001
# ch_number 3
# character (
#
#  P
# elemental_mass3 30.973761
# stoich3 1
# mass3 30.973761
#
#  O
# elemental_mass2 15.9994
# stoich2 4.0
# mass2 63.9976
# group_mass 94.971361
# group_stoich 3.0
# 5
# mass 485.304083
# ch_number 4
# character P
# mass 485.304083
# ch_number 5
# character O
# mass 485.304083
# ch_number 6
# character 4
# mass 485.304083
# ch_number 7
# character )
# mass 485.304083
# ch_number 8
# character 3
# mass 485.304083
# ch_number 9
# character O
#
#  O
# elemental_mass3 15.9994
# stoich3 1
# mass3 15.9994
# mass 501.30348299999997
# ch_number 10
# character H
#
#  H
# elemental_mass 1.00794
# stoich 1
# mass 1.00794
# Hydroxyapatite mass: 502.311423
#
#
# Fluorite CaF2
#  =============
#
# mass 0
# ch_number 0
# character C
#
#  Ca
# elemental_mass1 40.078
# stoich1 1
# mass1 40.078
# mass 40.078
# ch_number 1
# character a
# mass 40.078
# ch_number 2
# character F
#
#  F
# elemental_mass2 18.9984032
# stoich2 2.0
# mass2 37.9968064
# mass 78.0748064
# ch_number 3
# character 2
# Fluorite mass: 78.0748064
#
#
# Chalcedony SiO2
#  ===============
#
# mass 0
# ch_number 0
# character S
#
#  Si
# elemental_mass1 28.0855
# stoich1 1
# mass1 28.0855
# mass 28.0855
# ch_number 1
# character i
# mass 28.0855
# ch_number 2
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 2.0
# mass2 31.9988
# mass 60.0843
# ch_number 3
# character 2
# Chalcedony mass: 60.0843
#
#
# Quartz SiO2
#  ===========
#
# mass 0
# ch_number 0
# character S
#
#  Si
# elemental_mass1 28.0855
# stoich1 1
# mass1 28.0855
# mass 28.0855
# ch_number 1
# character i
# mass 28.0855
# ch_number 2
# character O
#
#  O
# elemental_mass2 15.9994
# stoich2 2.0
# mass2 31.9988
# mass 60.0843
# ch_number 3
# character 2
# Quartz mass: 60.0843
#
#
# Gibbsite Al(OH)3
#  ================
#
# mass 0
# ch_number 0
# character A
#
#  Al
# elemental_mass1 26.981538
# stoich1 1
# mass1 26.981538
# mass 26.981538
# ch_number 1
# character l
# mass 26.981538
# ch_number 2
# character (
#
#  O
# elemental_mass3 15.9994
# stoich3 1
# mass3 15.9994
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3d4f87c4b123> in <module>
#       6 for database in glob('../databases/*.dat'):
#       7     elements, minerals = database_parsing(database)
# ----> 8     database_json_creation(database, elements, minerals)
#       9 #     except:
#      10 #         erroneous_databases.append(database)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\processing_databases.py in database_json_creation(database, elements, minerals)
#     241         database_json['minerals'][mineral['phases']] = {'formula': mineral['formula'], 'mass': ''}
#     242
# --> 243     database_json['minerals'] = mineral_masses(database_json['minerals'])
#     244
#     245     # export the JSON files
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\processing_databases.py in mineral_masses(minerals)
#     207                         continue
#     208
# --> 209                     skips, mass = parse_mineral_formula(formula, ch_no2, final = final)
#     210                     group_mass += mass
#     211                     skip_characters += skips
#
# TypeError: cannot unpack non-iterable NoneType object
