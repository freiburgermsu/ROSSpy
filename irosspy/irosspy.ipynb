# %% [markdown]
# # Directions

# %% [markdown]
# Follow the prompts to intuitively design, execute, and process a ROSSpy simulation.
# Press < enter > on a prompt to accept the default value.

# %% [markdown]
# # Execution

# %%
# %run iROSSpy.py
# Out:
# ╔════════════════════════════════════════════════════════════════════════════╗
# ║ * iROSSpy I: interactive Reverse Osmosis Scaling Simulation in Python, I * ║
# ║                       Andrew Philip Freiburger, 2022                       ║
# ╚════════════════════════════════════════════════════════════════════════════╝
#
# The program is loading. It may take a minute...
#
#
# - You will create an input file? (boolean)
#     Default = < True >
#
# Parameterize initial details:
# ...
# - Is your computer operating system windows or unix?
#         < windows > or < unix > ; Default = < windows >  __
# < Amm >
# < ColdChem >
# < core10 >
# < frezchem >
# < iso >
# < llnl >
# < minteq >
# < minteq.v4 >
# < phreeqc >
# < pitzer >
# < sit >
# < Tipping_Hurley >
# < wateq4f >
# - What database do you select?
#         Default = < pitzer >  __
# - Will you simulate < scaling > or < brine >?
#         Default = < scaling >  __
# - Will you simulate evaporation or transport?
# ...
