# %% [markdown]
# # Execute the simulation

# %%
# %run ../../../rosspy/ro.py

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_type = 'transport'
simulation_time = 200

# create the input file
ross = ROSSPkg(database_selection, simulation_type = simulation_type, export_content = True, jupyter = True)
for perspective in ['all_distance', 'all_time']:
    ross.reactive_transport(simulation_time, perspective)
    ross.feed_geochemistry(water_selection)
    ross.execute(perspective, figure_title = f'Scaling over {perspective}')
# Out:
# Effluent module 1 CF: 1.1259334333617244
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-22 11:29:20.904844 local time.
# run_time (s): 7.943357200128958
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# OrderedDict([('0.0423 (m)',
#               {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}}),
#              ('0.127 (m)',
#               {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}}),
#              ('0.212 (m)',
#               {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}}),
#              ('0.296 (m)',
#               {'ion (g/m^2)': {'Ca': 0.4601709646106267,
#                                'H': 0.0231461012061298,
#                                'O': 0.9185163095951968,
#                                'S': 0.36816662458804683}}),
#              ('0.381 (m)',
#               {'ion (g/m^2)': {'Ca': 2.859819554077341,
#                                'H': 0.14384582670476145,
#                                'O': 5.708293449461675,
#                                'S': 2.2880411697562235}}),
#              ('0.466 (m)',
#               {'ion (g/m^2)': {'Ca': 2.521840879504564,
#                                'H': 0.126845865366926,
#                                'O': 5.033676950888931,
#                                'S': 2.0176363042395784}}),
#              ('0.55 (m)',
#               {'ion (g/m^2)': {'Ca': 2.191661712806544,
#                                'H': 0.11023821082919445,
#                                'O': 4.374628525360174,
#                                'S': 1.7534715510040875}}),
#              ('0.635 (m)',
#               {'ion (g/m^2)': {'Ca': 1.8718818899415322,
#                                'H': 0.09415363202493478,
#                                'O': 3.736337530556733,
#                                'S': 1.4976269474768007}}),
#              ('0.72 (m)',
#               {'ion (g/m^2)': {'Ca': 1.5573017389930248,
#                                'H': 0.07833059108741101,
#                                'O': 3.1084252511159485,
#                                'S': 1.2459424188036161}}),
#              ('0.804 (m)',
#               {'ion (g/m^2)': {'Ca': 1.2531209318775258,
#                                'H': 0.06303062588335911,
#                                'O': 2.5012704024004795,
#                                'S': 1.0025780398386361}}),
#              ('0.889 (m)',
#               {'ion (g/m^2)': {'Ca': 0.9567396326367832,
#                                'H': 0.04812296747941111,
#                                'O': 1.909683626728997,
#                                'S': 0.7654537731548093}}),
#              ('0.974 (m)',
#               {'ion (g/m^2)': {'Ca': 0.6681578412707968,
#                                'H': 0.033607615875566994,
#                                'O': 1.3336649241015004,
#                                'S': 0.5345696187521358}})])
# Effluent module 1 CF: 1.1259334333617244
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-22 11:29:29.031649 local time.
# run_time (s): 7.834277899935842
# ionic masses
#  ==============
# OrderedDict([('35 (s)',
#               {'ion (g/m^2)': {'Ca': 0.008059491470581596,
#                                'H': 0.00040538369344069136,
#                                'O': 0.016087008812119268,
#                                'S': 0.006448116023858448}}),
#              ('38 (s)',
#               {'ion (g/m^2)': {'Ca': 0.020200725395619037,
#                                'H': 0.001016074612269088,
#                                'O': 0.04032130918392474,
#                                'S': 0.016161890808187144}}),
#              ('41 (s)',
#               {'ion (g/m^2)': {'Ca': 0.032237965882326386,
#                                'H': 0.0016215347737627654,
#                                'O': 0.06434803524847707,
#                                'S': 0.02579246409543379}}),
#              ('44 (s)',
#               {'ion (g/m^2)': {'Ca': 0.04445719488611139,
#                                'H': 0.002236148760592201,
#                                'O': 0.08873801635072241,
#                                'S': 0.03556864000257402}}),
#              ('47 (s)',
#               {'ion (g/m^2)': {'Ca': 0.056416440294071175,
#                                'H': 0.0028376858540848397,
#                                'O': 0.11260906168483487,
#                                'S': 0.045136812167009134}}),
#              ('50 (s)',
#               {'ion (g/m^2)': {'Ca': 0.06837568570203097,
#                                'H': 0.0034392229475774787,
#                                'O': 0.13648010701894733,
#                                'S': 0.05470498433144425}}),
#              ('53 (s)',
#               {'ion (g/m^2)': {'Ca': 0.08033493110999075,
#                                'H': 0.004040760041070117,
#                                'O': 0.16035115235305977,
#                                'S': 0.06427315649587936}}),
#              ('56 (s)',
#               {'ion (g/m^2)': {'Ca': 0.09203419292212532,
#                                'H': 0.004629220241225959,
#                                'O': 0.18370326191903935,
#                                'S': 0.07363332491760936}}),
#              ('59 (s)',
#               {'ion (g/m^2)': {'Ca': 0.1037334547342599,
#                                'H': 0.005217680441381802,
#                                'O': 0.20705537148501896,
#                                'S': 0.08299349333933938}}),
#              ('62 (s)',
#               {'ion (g/m^2)': {'Ca': 0.11543271654639449,
#                                'H': 0.005806140641537645,
#                                'O': 0.23040748105099854,
#                                'S': 0.09235366176106938}}),
#              ('65 (s)',
#               {'ion (g/m^2)': {'Ca': 0.12713197835852905,
#                                'H': 0.006394600841693487,
#                                'O': 0.2537595906169781,
#                                'S': 0.10171383018279938}}),
#              ('68 (s)',
#               {'ion (g/m^2)': {'Ca': 0.13883124017066364,
#                                'H': 0.006983061041849329,
#                                'O': 0.2771117001829577,
#                                'S': 0.11107399860452939}}),
#              ('71 (s)',
#               {'ion (g/m^2)': {'Ca': 0.1505305019827982,
#                                'H': 0.007571521242005171,
#                                'O': 0.30046380974893727,
#                                'S': 0.12043416702625938}}),
#              ('74 (s)',
#               {'ion (g/m^2)': {'Ca': 0.162489747390758,
#                                'H': 0.00817305833549781,
#                                'O': 0.3243348550830497,
#                                'S': 0.1300023391906945}}),
#              ('77 (s)',
#               {'ion (g/m^2)': {'Ca': 0.1741890092028926,
#                                'H': 0.008761518535653653,
#                                'O': 0.3476869646490293,
#                                'S': 0.13936250761242452}}),
#              ('80 (s)',
#               {'ion (g/m^2)': {'Ca': 0.18588827101502714,
#                                'H': 0.009349978735809495,
#                                'O': 0.37103907421500887,
#                                'S': 0.1487226760341545}}),
#              ('83 (s)',
#               {'ion (g/m^2)': {'Ca': 0.19784751642298695,
#                                'H': 0.009951515829302133,
#                                'O': 0.39491011954912136,
#                                'S': 0.15829084819858963}}),
#              ('86 (s)',
#               {'ion (g/m^2)': {'Ca': 0.20980676183094674,
#                                'H': 0.010553052922794773,
#                                'O': 0.41878116488323386,
#                                'S': 0.16785902036302475}}),
#              ('89 (s)',
#               {'ion (g/m^2)': {'Ca': 0.22176600723890652,
#                                'H': 0.011154590016287411,
#                                'O': 0.44265221021734624,
#                                'S': 0.17742719252745986}}),
#              ('92 (s)',
#               {'ion (g/m^2)': {'Ca': 0.2337252526468663,
#                                'H': 0.01175612710978005,
#                                'O': 0.46652325555145874,
#                                'S': 0.18699536469189498}}),
#              ('95 (s)',
#               {'ion (g/m^2)': {'Ca': 0.2456844980548261,
#                                'H': 0.012357664203272688,
#                                'O': 0.4903943008855712,
#                                'S': 0.19656353685633007}}),
#              ('98 (s)',
#               {'ion (g/m^2)': {'Ca': 0.2576437434627859,
#                                'H': 0.012959201296765328,
#                                'O': 0.5142653462196837,
#                                'S': 0.20613170902076522}}),
#              ('102 (s)',
#               {'ion (g/m^2)': {'Ca': 0.2703829396582213,
#                                'H': 0.013599969070268357,
#                                'O': 0.5396931988581948,
#                                'S': 0.21632389241331568}}),
#              ('105 (s)',
#               {'ion (g/m^2)': {'Ca': 0.28078228349122986,
#                                'H': 0.014123044803740216,
#                                'O': 0.56045062958351,
#                                'S': 0.22464404212152012}}),
#              ('108 (s)',
#               {'ion (g/m^2)': {'Ca': 0.29378146328249044,
#                                'H': 0.01477688947058004,
#                                'O': 0.5863974179901539,
#                                'S': 0.23504422925677565}}),
#              ('111 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3067806430737511,
#                                'H': 0.015430734137419865,
#                                'O': 0.6123442063967979,
#                                'S': 0.2454444163920312}}),
#              ('114 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3171799869067596,
#                                'H': 0.015953809870891726,
#                                'O': 0.6331016371221131,
#                                'S': 0.2537645661002357}}),
#              ('117 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3301791666980203,
#                                'H': 0.01660765453773155,
#                                'O': 0.6590484255287571,
#                                'S': 0.26416475323549127}}),
#              ('120 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3431783464892809,
#                                'H': 0.017261499204571377,
#                                'O': 0.6849952139354011,
#                                'S': 0.2745649403707468}}),
#              ('123 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3535776903222894,
#                                'H': 0.017784574938043234,
#                                'O': 0.7057526446607163,
#                                'S': 0.28288509007895124}}),
#              ('126 (s)',
#               {'ion (g/m^2)': {'Ca': 0.36657687011355,
#                                'H': 0.018438419604883058,
#                                'O': 0.7316994330673602,
#                                'S': 0.2932852772142068}}),
#              ('129 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3795760499048107,
#                                'H': 0.019092264271722885,
#                                'O': 0.7576462214740042,
#                                'S': 0.30368546434946236}}),
#              ('132 (s)',
#               {'ion (g/m^2)': {'Ca': 0.3899753937378192,
#                                'H': 0.019615340005194742,
#                                'O': 0.7784036521993194,
#                                'S': 0.3120056140576668}}),
#              ('135 (s)',
#               {'ion (g/m^2)': {'Ca': 0.40297457352907984,
#                                'H': 0.02026918467203457,
#                                'O': 0.8043504406059634,
#                                'S': 0.3224058011929224}}),
#              ('138 (s)',
#               {'ion (g/m^2)': {'Ca': 0.4159737533203405,
#                                'H': 0.020923029338874397,
#                                'O': 0.8302972290126074,
#                                'S': 0.332805988328178}}),
#              ('141 (s)',
#               {'ion (g/m^2)': {'Ca': 0.426373097153349,
#                                'H': 0.021446105072346254,
#                                'O': 0.8510546597379224,
#                                'S': 0.34112613803638236}}),
#              ('144 (s)',
#               {'ion (g/m^2)': {'Ca': 0.4393722769446096,
#                                'H': 0.022099949739186078,
#                                'O': 0.8770014481445664,
#                                'S': 0.35152632517163795}}),
#              ('147 (s)',
#               {'ion (g/m^2)': {'Ca': 0.4497716207776181,
#                                'H': 0.02262302547265794,
#                                'O': 0.8977588788698816,
#                                'S': 0.3598464748798424}}),
#              ('150 (s)',
#               {'ion (g/m^2)': {'Ca': 0.4627708005688788,
#                                'H': 0.023276870139497762,
#                                'O': 0.9237056672765256,
#                                'S': 0.370246662015098}}),
#              ('153 (s)',
#               {'ion (g/m^2)': {'Ca': 0.47576998036013946,
#                                'H': 0.02393071480633759,
#                                'O': 0.9496524556831696,
#                                'S': 0.3806468491503535}}),
#              ('156 (s)',
#               {'ion (g/m^2)': {'Ca': 0.48616932419314796,
#                                'H': 0.02445379053980945,
#                                'O': 0.9704098864084848,
#                                'S': 0.388966998858558}}),
#              ('159 (s)',
#               {'ion (g/m^2)': {'Ca': 0.49916850398440854,
#                                'H': 0.02510763520664927,
#                                'O': 0.9963566748151287,
#                                'S': 0.3993671859938135}}),
#              ('162 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5121676837756692,
#                                'H': 0.025761479873489097,
#                                'O': 1.0223034632217727,
#                                'S': 0.4097673731290691}}),
#              ('165 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5225670276086777,
#                                'H': 0.026284555606960955,
#                                'O': 1.0430608939470878,
#                                'S': 0.41808752283727346}}),
#              ('168 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5355662073999384,
#                                'H': 0.026938400273800782,
#                                'O': 1.069007682353732,
#                                'S': 0.4284877099725291}}),
#              ('170 (s)',
#               {'ion (g/m^2)': {'Ca': 0.548565387191199,
#                                'H': 0.027592244940640605,
#                                'O': 1.0949544707603758,
#                                'S': 0.43888789710778464}}),
#              ('173 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5589647310242075,
#                                'H': 0.028115320674112466,
#                                'O': 1.115711901485691,
#                                'S': 0.4472080468159891}}),
#              ('176 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5719639108154682,
#                                'H': 0.028769165340952293,
#                                'O': 1.141658689892335,
#                                'S': 0.4576082339512447}}),
#              ('179 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5849630906067288,
#                                'H': 0.029423010007792117,
#                                'O': 1.167605478298979,
#                                'S': 0.4680084210865002}}),
#              ('182 (s)',
#               {'ion (g/m^2)': {'Ca': 0.5953624344397374,
#                                'H': 0.029946085741263978,
#                                'O': 1.1883629090242942,
#                                'S': 0.4763285707947047}}),
#              ('185 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6083616142309979,
#                                'H': 0.030599930408103798,
#                                'O': 1.2143096974309382,
#                                'S': 0.4867287579299602}}),
#              ('188 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6213607940222586,
#                                'H': 0.031253775074943625,
#                                'O': 1.2402564858375822,
#                                'S': 0.4971289450652158}}),
#              ('191 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6317601378552672,
#                                'H': 0.03177685080841549,
#                                'O': 1.2610139165628975,
#                                'S': 0.5054490947734203}}),
#              ('194 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6447593176465277,
#                                'H': 0.03243069547525531,
#                                'O': 1.2869607049695413,
#                                'S': 0.5158492819086758}}),
#              ('197 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6577584974377884,
#                                'H': 0.03308454014209513,
#                                'O': 1.3129074933761853,
#                                'S': 0.5262494690439313}}),
#              ('200 (s)',
#               {'ion (g/m^2)': {'Ca': 0.6681578412707968,
#                                'H': 0.033607615875566994,
#                                'O': 1.3336649241015004,
#                                'S': 0.5345696187521358}})])
