# %% [markdown]
# # exchange_factor parameter of the Dual domain

# %% [markdown]
# ## Large value

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'mobile'
simulation_perspective = 'all_distance'
simulation_time = 75
exchange_factor = 1e10

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective, exchange_factor = exchange_factor)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
# Out:
# Estimated completion in 17.0 seconds by 2021-10-15 21:57:04.714203 local time.

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'immobile'
simulation_perspective = 'all_distance'
simulation_time = 75
exchange_factor = 1e10

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective, exchange_factor = exchange_factor)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 1.70E1 seconds by 2021-10-26 21:50:20.676825 local time.
# C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\databases\pitzer.dat

# %% [markdown]
# ## Small value

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'mobile'
simulation_perspective = 'all_distance'
simulation_time = 75
exchange_factor = 1e-10

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective, exchange_factor = exchange_factor)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
# Out:
# Estimated completion in 17.0 seconds by 2021-10-15 21:57:00.936645 local time.

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg()

# general parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'immobile'
simulation_perspective = 'all_distance'
simulation_time = 75
exchange_factor = 1e-10

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective, exchange_factor = exchange_factor)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 1.70E1 seconds by 2021-10-26 21:50:30.379203 local time.
# C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\databases\pitzer.dat
