# %% [markdown]
# # Define and execute the simulation

# %%
# execute the ROSSpy simulation
# %run ../../../../rosspy/ro.py
# from rosspy import ROSSPkg

# initial parameters
database_selection = 'pitzer'
simulation_perspective = 'all_distance'
simulation_time = 200

# Define the feed conditions
water_selection = 'Spacer_filled_channels'
water_characteristics = {
    'element': {
        'Ca': {
            'concentration (ppm)': 800
            }, 
        'S(6)': {
            'concentration (ppm)': 1975
        }
    },
    'pH': {
        'value': 6.4
    },
}

# create the input file
ross = ROSSPkg(database_selection, operating_system = 'unix', export_content = True)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection, water_characteristics)
ross.execute(export_format="eps")

# execute and process the input file
display(ross.processed_data)
display(ross.selected_output)
# Out:
# Effluent module 1 CF: 1.1176963344974205
#
# Estimated completion in 7 seconds: 2022-11-24 11:35:13.208088 local time.
# run_time (s): 0.5330164000000002
# Gypsum		{'formula': 'CaSO4:2H2O', 'mass': '170'}
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ionic masses
#  ==============
# OrderedDict([('0.0423 (m)',
#               {'ion (g/m^2)': {'Ca': 64.9958989563032,
#                                'H': 3.269223334199124,
#                                'O': 129.7339420332199,
#                                'S': 52.000935676277805}}),
#              ('0.127 (m)',
#               {'ion (g/m^2)': {'Ca': 1.7028925526551437,
#                                'H': 0.08565365135601705,
#                                'O': 3.399029281270361,
#                                'S': 1.3624245147184784}}),
#              ('0.212 (m)',
#               {'ion (g/m^2)': {'Ca': 1.663895013281362,
#                                'H': 0.08369211735549759,
#                                'O': 3.3211889160504295,
#                                'S': 1.331223953312712}}),
#              ('0.296 (m)',
#               {'ion (g/m^2)': {'Ca': 1.622297637949328,
#                                'H': 0.08159981442161014,
#                                'O': 3.2381591931491687,
#                                'S': 1.297943354479894}}),
#              ('0.381 (m)',
#               {'ion (g/m^2)': {'Ca': 1.5833000985755459,
#                                'H': 0.07963828042109065,
#                                'O': 3.1603188279292365,
#                                'S': 1.2667427930741273}}),
#              ('0.466 (m)',
#               {'ion (g/m^2)': {'Ca': 1.544302559201764,
#                                'H': 0.0776767464205712,
#                                'O': 3.0824784627093047,
#                                'S': 1.2355422316683606}}),
#              ('0.55 (m)',
#               {'ion (g/m^2)': {'Ca': 1.5079048557862342,
#                                'H': 0.07584598135341968,
#                                'O': 3.009827455170701,
#                                'S': 1.206421707689645}}),
#              ('0.635 (m)',
#               {'ion (g/m^2)': {'Ca': 1.4689073164124524,
#                                'H': 0.0738844473529002,
#                                'O': 2.93198708995077,
#                                'S': 1.1752211462838784}}),
#              ('0.72 (m)',
#               {'ion (g/m^2)': {'Ca': 1.4325096129969224,
#                                'H': 0.0720536822857487,
#                                'O': 2.8593360824121663,
#                                'S': 1.1461006223051626}}),
#              ('0.804 (m)',
#               {'ion (g/m^2)': {'Ca': 1.3961119095813928,
#                                'H': 0.07022291721859719,
#                                'O': 2.786685074873563,
#                                'S': 1.1169800983264473}}),
#              ('0.889 (m)',
#               {'ion (g/m^2)': {'Ca': 1.3571143702076107,
#                                'H': 0.0682613832180777,
#                                'O': 2.708844709653631,
#                                'S': 1.0857795369206804}}),
#              ('0.974 (m)',
#               {'ion (g/m^2)': {'Ca': 1.323316502750333,
#                                'H': 0.06656138708429417,
#                                'O': 2.641383059796357,
#                                'S': 1.058739050369016}})])
#                Gypsum (g/m^2)
# Distance ($m$)
# 4.23E-2               2.500E2
# 1.27E-1               6.550E0
# 2.12E-1               6.400E0
# 2.96E-1               6.240E0
# 3.81E-1               6.090E0
# 4.66E-1               5.940E0
# 5.50E-1               5.800E0
# 6.35E-1               5.650E0
# 7.20E-1               5.510E0
# 8.04E-1               5.370E0
# 8.89E-1               5.220E0
# 9.74E-1               5.090E0
#     sim   state  soln    dist_x       time  step        pH   pe  reaction  \
# 3     1  transp     1  0.042333    0.00000     0  7.000000  4.0  6.724109
# 4     1  transp     2  0.127000    0.00000     0  7.000000  4.0  6.668075
# 5     1  transp     3  0.211667    0.00000     0  7.000000  4.0  6.612041
# 6     1  transp     4  0.296333    0.00000     0  7.000000  4.0  6.556006
# 7     1  transp     5  0.381000    0.00000     0  7.000000  4.0  6.499972
# 8     1  transp     6  0.465667    0.00000     0  7.000000  4.0  6.443938
# 9     1  transp     7  0.550333    0.00000     0  7.000000  4.0  6.387904
# 10    1  transp     8  0.635000    0.00000     0  7.000000  4.0  6.331869
# 11    1  transp     9  0.719667    0.00000     0  7.000000  4.0  6.275835
# 12    1  transp    10  0.804333    0.00000     0  7.000000  4.0  6.219801
