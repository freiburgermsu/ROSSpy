# %% [markdown]
# # Scaling with all of the databases

# %%
from glob import glob
import re
import os

# run the ROSS model
# %matplotlib inline
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
databases_path = os.path.join(os.getcwd(),'..','..','..','rosspy','databases','*.json')
for database in glob(databases_path):
    database_selection = re.search('(?<=databases\\\\)(.+)(?=\.json)',database).group()
    print('='*30, f'\n\n{database_selection} database \n', '='*(len(database_selection)+10))

    # define the simulation
    ross.define_general(database_selection, simulation)
    ross.transport(simulation_time, simulation_perspective)
    ross.reaction()
    ross.solutions(water_selection)
    ross.equilibrium_phases()
    ross.selected_output()
    ross.export()
    
    # execute and process the input file
    try:
        raw_data = ross.execute()
        scaling_data = ross.process_selected_output()
    except:
        print('--> ERROR: The simulation with the {} database failed to converge'.format(database_selection))
        scaling_data = None
        
    display(scaling_data)
# Out:
# ==============================
#
# Amm database
#  =============
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:15.005712 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.22E0
# 2.12E-1              8.94E0
# 2.96E-1              8.65E0
# 3.81E-1              8.37E0
# 4.66E-1              8.10E0
# 5.50E-1              7.82E0
# 6.35E-1              7.56E0
# 7.20E-1              7.29E0
# 8.04E-1              7.03E0
# 8.89E-1              6.78E0
# ==============================
#
# ColdChem database
#  ==================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The Mn element is not accepted by the ColdChem database
#
# --> ERROR: The Fe element is not accepted by the ColdChem database
#
# --> ERROR: The B element is not accepted by the ColdChem database
#
# --> ERROR: The Sr element is not accepted by the ColdChem database
#
# --> ERROR: The Ba element is not accepted by the ColdChem database
#
# --> ERROR: The Li element is not accepted by the ColdChem database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:19.208135 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1              0.00E0
# 5.50E-1              0.00E0
# 6.35E-1              0.00E0
# 7.20E-1              0.00E0
# 8.04E-1              4.87E0
# 8.89E-1              7.66E0
# ==============================
#
# core10 database
#  ================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The S(6) element is not accepted by the core10 database
#
# --> ERROR: The Sr element is not accepted by the core10 database
#
# --> ERROR: The Ba element is not accepted by the core10 database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:22.207718 local time.
#              Brucite (g/m^2) Portlandite (g/m^2)
# Distance (m)
# 1.27E-1              1.26E-6              3.51E0
# 2.12E-1              1.22E-6              3.40E0
# 2.96E-1              1.18E-6              3.29E0
# 3.81E-1              1.14E-6              3.19E0
# 4.66E-1              1.10E-6              3.08E0
# 5.50E-1              1.07E-6              2.98E0
# 6.35E-1              1.03E-6              2.88E0
# 7.20E-1              9.95E-7              2.78E0
# 8.04E-1              9.59E-7              2.68E0
# 8.89E-1              9.24E-7              2.59E0
# ==============================
#
# frezchem database
#  ==================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The Mn element is not accepted by the frezchem database
#
# --> ERROR: The Fe element is not accepted by the frezchem database
#
# --> ERROR: The B element is not accepted by the frezchem database
#
# --> ERROR: The Sr element is not accepted by the frezchem database
#
# --> ERROR: The Ba element is not accepted by the frezchem database
#
# --> ERROR: The Li element is not accepted by the frezchem database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:26.174914 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.16E0
# 2.12E-1              8.88E0
# 2.96E-1              8.60E0
# 3.81E-1              8.33E0
# 4.66E-1              8.07E0
# 5.50E-1              7.81E0
# 6.35E-1              7.55E0
# 7.20E-1              7.29E0
# 8.04E-1              7.04E0
# 8.89E-1              6.79E0
# ==============================
#
# iso database
#  =============
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The Mn element is not accepted by the iso database
#
# --> ERROR: The B element is not accepted by the iso database
#
# --> ERROR: The Sr element is not accepted by the iso database
#
# --> ERROR: The Ba element is not accepted by the iso database
#
# --> ERROR: The Li element is not accepted by the iso database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:29.578784 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.74E0
# 2.12E-1              9.43E0
# 2.96E-1              9.14E0
# 3.81E-1              8.84E0
# 4.66E-1              8.55E0
# 5.50E-1              8.27E0
# 6.35E-1              7.98E0
# 7.20E-1              7.71E0
# 8.04E-1              7.43E0
# 8.89E-1              7.16E0
# ==============================
#
# llnl database
#  ==============
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The S(6) element is not accepted by the llnl database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:32.784157 local time.
#              Brucite (g/m^2) Portlandite (g/m^2)
# Distance (m)
# 1.27E-1              1.20E-6              3.90E0
# 2.12E-1              1.16E-6              3.77E0
# 2.96E-1              1.12E-6              3.66E0
# 3.81E-1              1.09E-6              3.54E0
# 4.66E-1              1.05E-6              3.44E0
# 5.50E-1              1.01E-6              3.33E0
# 6.35E-1              9.77E-7              3.21E0
# 7.20E-1              9.44E-7              3.10E0
# 8.04E-1              9.12E-7              2.98E0
# 8.89E-1              8.76E-7              2.89E0
# ==============================
#
# minteq database
#  ================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:41.719077 local time.
#              Anhydrite (g/m^2)
# Distance (m)
# 1.27E-1                 7.05E0
# 2.12E-1                 6.83E0
# 2.96E-1                 6.61E0
# 3.81E-1                 6.40E0
# 4.66E-1                 6.19E0
# 5.50E-1                 5.98E0
# 6.35E-1                 5.77E0
# 7.20E-1                 5.57E0
# 8.04E-1                 5.37E0
# 8.89E-1                 5.17E0
# ==============================
#
# minteq.v4 database
#  ===================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:45.968385 local time.
# --> ERROR: The simulation with the minteq.v4 database failed to converge
# None
# ==============================
#
# phreeqc database
#  =================
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:46.985594 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.22E0
# 2.12E-1              8.94E0
# 2.96E-1              8.65E0
# 3.81E-1              8.37E0
# 4.66E-1              8.10E0
# 5.50E-1              7.82E0
# 6.35E-1              7.56E0
# 7.20E-1              7.29E0
# 8.04E-1              7.03E0
# 8.89E-1              6.78E0
# ==============================
#
# pitzer database
#  ================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:49.974119 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             4.39E-1
# 5.50E-1              8.21E0
# 6.35E-1              7.98E0
# 7.20E-1              7.71E0
# 8.04E-1              7.45E0
# 8.89E-1              7.19E0
# ==============================
#
# sit database
#  =============
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The S(6) element is not accepted by the sit database
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:56.238615 local time.
# --> ERROR: The simulation with the sit database failed to converge
# None
# ==============================
#
# Tipping_Hurley database
#  ========================
#
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:11:59.699906 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.51E0
# 2.12E-1              9.21E0
# 2.96E-1              8.92E0
# 3.81E-1              8.63E0
# 4.66E-1              8.34E0
# 5.50E-1              8.06E0
# 6.35E-1              7.79E0
# 7.20E-1              7.52E0
# 8.04E-1              7.25E0
# 8.89E-1              6.98E0
# ==============================
#
# wateq4f database
#  =================
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 22:12:03.762034 local time.
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              9.51E0
# 2.12E-1              9.21E0
# 2.96E-1              8.92E0
# 3.81E-1              8.63E0
# 4.66E-1              8.34E0
# 5.50E-1              8.06E0
# 6.35E-1              7.79E0
# 7.20E-1              7.52E0
# 8.04E-1              7.25E0
# 8.89E-1              6.98E0
