# %%
# %run ../../rosspy/ro.py
# import rosspy

# execute the simulation
ross = ROSSPkg('pitzer', simulation = 'scaling', jupyter = True, export_content = True)
ross.parse_input(input_file_path = '2020-09-03_APF_German North Basin_BW30-400_PE=100%_1.1', water_selection = 'North German Basin')
ross.execute()
# Out:
# Estimated completion in 5 seconds: 2022-04-22 21:58:23.372283 local time.
# run_time (s): 3.495183799881488
# Barite		{'formula': 'BaSO4', 'mass': '230'}
# Dolomite	{'formula': 'CaMg(CO3)2', 'mass': '120'}
# Halite		{'formula': 'NaCl', 'mass': '58'}
# C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\ro.py:1116: RuntimeWarning: divide by zero encountered in log10
#   # finalize the output data
# ionic masses
# ...
# OrderedDict([('0.0423 (m)',
#               {'ion (g/m^2)': {'Ba': 117.09207693916096,
#                                'C': 0.0010717640778861001,
#                                'Ca': 0.0035763245034443566,
#                                'Cl': 734.0194518500748,
#                                'Mg': 0.002168834948256277,
#                                'Na': 475.9805481499251,
#                                'O': 54.5719347627495,
#                                'S': 27.340271374559958}}),
# ...
