# %% [markdown]
# # Define the simulation parameters

# %%
# execute the ROSSpy simulation
# %run ../../../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# Define the feed conditions
water_selection = 'waterwater'
water_characteristics = {
    'element': {
        'Li': {
            'concentration (ppm)': 0.04
        },
        'Na': {
            'concentration (ppm)': 701
        },
        'Mg': {
            'concentration (ppm)': 96
        },
        'Ca': {
            'concentration (ppm)': 250
        }, 
        'K': {
            'concentration (ppm)': 34
        },
        'Mn': {
            'concentration (ppm)': 0.09
        }, 
        'Fe': {
            'concentration (ppm)': 9.8
        }, 
        'Co': {
            'concentration (ppm)': 0.13
        }, 
        'Cu': {
            'concentration (ppm)': 0.03
        }, 
        'S(6)': {
            'concentration (ppm)': 433.8,
            'form': 'SO4'
        }, 
        'Cl': {
            'concentration (ppm)': 1400
        }, 
        'F': {
            'concentration (ppm)': 0.7
        },
        'N(5)': {
            'concentration (ppm)': 9.2,
            'form': 'NO3'
        },
        'Ba': {
            'concentration (ppm)': 0.05
        },
        'B': {
            'concentration (ppm)': 0.55
        },
        'Sr': {
            'concentration (ppm)': 6.2
        },
        'Si': {
            'concentration (ppm)': 26,
            'form': 'SiO2'
        },
        'C(4)': {
            'concentration (ppm)': 0.2,
            'form': 'CO3'
        },
    },
    'temperature': {
        'value': 31
    },
    'Alkalinity': {
        'value': 192.7,
        'form': 'HCO3'
    },
    'pH': {
        'value': 6.8
    },
}

# define the module characteristics
permeate_recovery = 0.68
module_characteristics = {
    'max_feed_flow_m3_per_hour':10.5,
    'permeate_flow_m3_per_hour': permeate_recovery*10.58,
    'active_m2': 37
}

# general parameters
simulation_perspective = 'all_distance'
simulation_time = 200

# %% [markdown]
# # Execution with all of the databases

# %%
from glob import glob
import os, re

# loop through the databases
for db in ross.databases: 
    # create the input file
    ross.define_general(db)
    ross.transport(simulation_time, simulation_perspective, module_characteristics)
    ross.reaction()
    ross.solutions(water_selection, water_characteristics)
    ross.equilibrium_phases()
    ross.selected_output()
    ross.export()

    # execute and process the input file
    raw_data = ross.execute()
    distance_data = ross.process_selected_output()
    display(distance_data)
# Out:
# --> ERROR: The Co element is not accepted by the Amm database
#
# --> ERROR: The N(5) element is not accepted by the Amm database
#
# --> ERROR: The C(4) element is not accepted by the Amm database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:24:47.390602 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          8.19E-2        1.19E-3
# 2.12E-1               0.00E0          7.77E-2        1.12E-3
# 2.96E-1               0.00E0          7.35E-2        1.04E-3
# 3.81E-1               0.00E0          6.93E-2        9.75E-4
# 4.66E-1               0.00E0          6.52E-2        9.07E-4
# 5.50E-1              1.59E-1          5.00E-2        8.45E-4
# 6.35E-1              7.13E-1          1.04E-2        7.90E-4
# 7.20E-1              8.60E-1          2.79E-3        7.29E-4
# 8.04E-1              9.08E-1          2.74E-3        6.70E-4
# 8.89E-1              9.65E-1          2.62E-3        6.12E-4
# --> ERROR: The Li element is not accepted by the ColdChem database
#
# --> ERROR: The Mn element is not accepted by the ColdChem database
#
# --> ERROR: The Fe element is not accepted by the ColdChem database
#
# --> ERROR: The Co element is not accepted by the ColdChem database
#
# --> ERROR: The Cu element is not accepted by the ColdChem database
#
# --> ERROR: The F element is not accepted by the ColdChem database
#
# --> ERROR: The N(5) element is not accepted by the ColdChem database
#
# --> ERROR: The Ba element is not accepted by the ColdChem database
#
# --> ERROR: The B element is not accepted by the ColdChem database
#
# --> ERROR: The Sr element is not accepted by the ColdChem database
#
# --> ERROR: The Si element is not accepted by the ColdChem database
#
# --> ERROR: The C(4) element is not accepted by the ColdChem database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:24:50.366577 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# No scaling occurred.
# None
# --> ERROR: The S(6) element is not accepted by the core10 database
#
# --> ERROR: The F element is not accepted by the core10 database
#
# --> ERROR: The N(5) element is not accepted by the core10 database
#
# --> ERROR: The Ba element is not accepted by the core10 database
#
# --> ERROR: The Sr element is not accepted by the core10 database
#
# --> ERROR: The C(4) element is not accepted by the core10 database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:24:51.985745 local time.
#              Dolomite (g/m^2) Siderite (g/m^2)
# Distance (m)
# 1.27E-1               6.24E-1          7.46E-3
# 2.12E-1               6.29E-1          6.82E-3
# 2.96E-1               6.35E-1          6.17E-3
# 3.81E-1               6.42E-1          5.51E-3
# 4.66E-1               6.49E-1          4.83E-3
# 5.50E-1               6.57E-1          4.12E-3
# 6.35E-1               6.66E-1          3.37E-3
# 7.20E-1               6.76E-1          2.59E-3
# 8.04E-1               6.88E-1          2.72E-3
# 8.89E-1               7.03E-1          1.68E-3
# --> ERROR: The Li element is not accepted by the frezchem database
#
# --> ERROR: The Mn element is not accepted by the frezchem database
#
# --> ERROR: The Fe element is not accepted by the frezchem database
#
# --> ERROR: The Co element is not accepted by the frezchem database
#
# --> ERROR: The Cu element is not accepted by the frezchem database
#
# --> ERROR: The F element is not accepted by the frezchem database
#
# --> ERROR: The N(5) element is not accepted by the frezchem database
#
# --> ERROR: The Ba element is not accepted by the frezchem database
#
# --> ERROR: The B element is not accepted by the frezchem database
#
# --> ERROR: The Sr element is not accepted by the frezchem database
#
# --> ERROR: The Si element is not accepted by the frezchem database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:24:57.223741 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Hydromagnesite (g/m^2)
# Distance (m)
# 1.27E-1                     1.08E-3
# 2.12E-1                     9.75E-4
# 2.96E-1                     8.77E-4
# 3.81E-1                     7.85E-4
# 4.66E-1                     7.01E-4
# 5.50E-1                     6.22E-4
# 6.35E-1                     5.49E-4
# 7.20E-1                     4.81E-4
# 8.04E-1                     4.19E-4
# 8.89E-1                     3.61E-4
# --> ERROR: The Li element is not accepted by the iso database
#
# --> ERROR: The Mn element is not accepted by the iso database
#
# --> ERROR: The Co element is not accepted by the iso database
#
# --> ERROR: The Cu element is not accepted by the iso database
#
# --> ERROR: The N(5) element is not accepted by the iso database
#
# --> ERROR: The Ba element is not accepted by the iso database
#
# --> ERROR: The B element is not accepted by the iso database
#
# --> ERROR: The Sr element is not accepted by the iso database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:24:59.513535 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0
# 2.12E-1               0.00E0
# 2.96E-1               0.00E0
# 3.81E-1               0.00E0
# 4.66E-1               0.00E0
# 5.50E-1               0.00E0
# 6.35E-1               0.00E0
# 7.20E-1               0.00E0
# 8.04E-1               0.00E0
# 8.89E-1               0.00E0
# --> ERROR: The S(6) element is not accepted by the llnl database
#
# --> ERROR: The N(5) element is not accepted by the llnl database
#
# --> ERROR: The C(4) element is not accepted by the llnl database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:04.552416 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Dolomite (g/m^2) Witherite (g/m^2)
# Distance (m)
# 1.27E-1               5.87E-1            0.00E0
# 2.12E-1               5.92E-1            0.00E0
# 2.96E-1               5.98E-1            0.00E0
# 3.81E-1               6.04E-1            0.00E0
# 4.66E-1               6.11E-1            0.00E0
# 5.50E-1               6.19E-1            0.00E0
# 6.35E-1               6.27E-1            0.00E0
# 7.20E-1               6.37E-1            0.00E0
# 8.04E-1               6.49E-1           1.21E-4
# 8.89E-1               6.64E-1           1.12E-4
# --> ERROR: The Co element is not accepted by the minteq database
#
# --> ERROR: The N(5) element is not accepted by the minteq database
#
# --> ERROR: The C(4) element is not accepted by the minteq database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:14.419519 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Calcite (g/m^2) Ferrihydrite (g/m^2)  \
# Distance (m)
# 1.27E-1             7.81E-4          0.00E0              3.25E-5
# 2.12E-1             7.26E-4          0.00E0              3.22E-5
# 2.96E-1             6.73E-4          0.00E0              3.19E-5
# 3.81E-1             6.22E-4          0.00E0              3.15E-5
# 4.66E-1             5.74E-4          0.00E0              3.12E-5
# 5.50E-1             5.31E-4         2.59E-1              1.92E-5
# 6.35E-1             4.90E-4         6.93E-1              4.81E-7
# 7.20E-1             4.48E-4         8.85E-1               0.00E0
# 8.04E-1             4.06E-4         9.33E-1               0.00E0
# 8.89E-1             3.66E-4         9.90E-1               0.00E0
#
#              Siderite (g/m^2)
# Distance (m)
# 1.27E-1               1.28E-1
# 2.12E-1               1.22E-1
# 2.96E-1               1.17E-1
# 3.81E-1               1.12E-1
# 4.66E-1               1.07E-1
# 5.50E-1               7.26E-2
# 6.35E-1               2.23E-2
# 7.20E-1               2.97E-3
# 8.04E-1               2.86E-3
# 8.89E-1               2.60E-3
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:19.702712 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Ferrihydrite (g/m^2) Brucite (g/m^2) Atacamite (g/m^2)  \
# Distance (m)
# 1.27E-1                   2.33E-6         5.68E-2           1.77E-4
# 2.12E-1                   2.09E-6         5.45E-2           1.58E-4
# 2.96E-1                   1.88E-6         5.22E-2           1.49E-4
# 3.81E-1                   1.70E-6         5.00E-2           1.45E-4
# 4.66E-1                   1.54E-6         4.79E-2           1.37E-4
# 5.50E-1                   1.51E-6         4.59E-2           1.29E-4
# 6.35E-1                   1.89E-6         4.41E-2           1.22E-4
# 7.20E-1                   1.91E-6         4.25E-2           1.14E-4
# 8.04E-1                   1.91E-6         4.11E-2           1.06E-4
# 8.89E-1                   1.92E-6         4.01E-2           9.73E-5
#
#              Barite (g/m^2)
# Distance (m)
# 1.27E-1             7.33E-4
# 2.12E-1             6.82E-4
# 2.96E-1             6.33E-4
# 3.81E-1             5.86E-4
# 4.66E-1             5.41E-4
# 5.50E-1             4.98E-4
# 6.35E-1             4.57E-4
# 7.20E-1             4.18E-4
# 8.04E-1             3.80E-4
# 8.89E-1             3.44E-4
# --> ERROR: The Co element is not accepted by the phreeqc database
#
# --> ERROR: The N(5) element is not accepted by the phreeqc database
#
# --> ERROR: The C(4) element is not accepted by the phreeqc database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:26.180890 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          8.19E-2        1.19E-3
# 2.12E-1               0.00E0          7.77E-2        1.12E-3
# 2.96E-1               0.00E0          7.35E-2        1.04E-3
# 3.81E-1               0.00E0          6.93E-2        9.75E-4
# 4.66E-1               0.00E0          6.52E-2        9.07E-4
# 5.50E-1              1.59E-1          5.00E-2        8.45E-4
# 6.35E-1              7.13E-1          1.04E-2        7.90E-4
# 7.20E-1              8.60E-1          2.79E-3        7.29E-4
# 8.04E-1              9.08E-1          2.74E-3        6.70E-4
# 8.89E-1              9.65E-1          2.62E-3        6.12E-4
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The F element is not accepted by the pitzer database
#
# --> ERROR: The N(5) element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:29.181596 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Brucite (g/m^2) Calcite (g/m^2)
# Distance (m)
# 1.27E-1             8.90E-4         7.48E-2          0.00E0
# 2.12E-1             8.30E-4         7.09E-2          0.00E0
# 2.96E-1             7.71E-4         6.72E-2          0.00E0
# 3.81E-1             7.15E-4         6.36E-2          0.00E0
# 4.66E-1             6.62E-4         6.00E-2          0.00E0
# 5.50E-1             6.11E-4         5.66E-2          0.00E0
# 6.35E-1             5.62E-4         5.33E-2          0.00E0
# 7.20E-1             5.15E-4         5.01E-2          0.00E0
# 8.04E-1             4.70E-4         4.70E-2          0.00E0
# 8.89E-1             4.28E-4         4.33E-2         6.61E-3
# --> ERROR: The S(6) element is not accepted by the sit database
#
# --> ERROR: The N(5) element is not accepted by the sit database
#
# --> ERROR: The C(4) element is not accepted by the sit database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:25:34.086491 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Dolomite (g/m^2) Ferryhydrite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0           0.00E0               0.00E0
# 2.12E-1               0.00E0           0.00E0               0.00E0
# 2.96E-1               0.00E0           0.00E0               0.00E0
# 3.81E-1               0.00E0           0.00E0               0.00E0
# 4.66E-1               0.00E0           0.00E0               0.00E0
# 5.50E-1               0.00E0           0.00E0               0.00E0
# 6.35E-1              5.87E-1           0.00E0               0.00E0
# 7.20E-1              7.89E-1           0.00E0               0.00E0
# 8.04E-1              8.33E-1           0.00E0               0.00E0
# 8.89E-1              8.73E-1          1.09E-2               0.00E0
# --> ERROR: The Co element is not accepted by the Tipping_Hurley database
#
# --> ERROR: The N(5) element is not accepted by the Tipping_Hurley database
#
# --> ERROR: The C(4) element is not accepted by the Tipping_Hurley database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:26:01.566695 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2) Dolomite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          8.18E-2        9.76E-4           0.00E0
# 2.12E-1               0.00E0          7.75E-2        9.12E-4           0.00E0
# 2.96E-1               0.00E0          7.34E-2        8.49E-4           0.00E0
# 3.81E-1               0.00E0          6.92E-2        7.89E-4           0.00E0
# 4.66E-1               0.00E0          6.51E-2        7.32E-4           0.00E0
# 5.50E-1              5.63E-4          6.10E-2        6.76E-4           0.00E0
# 6.35E-1              6.69E-1          1.35E-2        6.31E-4           0.00E0
# 7.20E-1              5.97E-1          1.70E-3        5.80E-4          2.52E-1
# 8.04E-1              6.09E-1          1.57E-3        5.29E-4          2.87E-1
# 8.89E-1              6.60E-1          1.43E-3        4.80E-4          2.92E-1
# --> ERROR: The Co element is not accepted by the wateq4f database
#
# --> ERROR: The N(5) element is not accepted by the wateq4f database
#
# --> ERROR: The C(4) element is not accepted by the wateq4f database
#
#
#
#
# Estimated completion in 3.40E1 seconds by 2021-12-29 15:26:06.587070 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2) Dolomite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          8.18E-2        9.76E-4           0.00E0
# 2.12E-1               0.00E0          7.75E-2        9.12E-4           0.00E0
# 2.96E-1               0.00E0          7.34E-2        8.49E-4           0.00E0
# 3.81E-1               0.00E0          6.92E-2        7.89E-4           0.00E0
# 4.66E-1               0.00E0          6.51E-2        7.32E-4           0.00E0
# 5.50E-1              5.63E-4          6.10E-2        6.76E-4           0.00E0
# 6.35E-1              6.69E-1          1.35E-2        6.31E-4           0.00E0
# 7.20E-1              5.97E-1          1.70E-3        5.80E-4          2.52E-1
# 8.04E-1              6.09E-1          1.57E-3        5.29E-4          2.87E-1
# 8.89E-1              6.60E-1          1.43E-3        4.80E-4          2.92E-1
