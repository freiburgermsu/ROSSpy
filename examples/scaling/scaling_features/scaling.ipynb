# %% [markdown]
# # Red Sea scaling through BW30-400

# %% [markdown]
# ## Evaluate scaling along the module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, quantity_of_modules = quantity_of_modules)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
distance_data = ross.process_selected_output()
display(distance_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 23:16:18.050184 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             4.39E-1
# 5.50E-1              8.21E0
# 6.35E-1              7.98E0
# 7.20E-1              7.71E0
# 8.04E-1              7.45E0
# 8.89E-1              7.19E0

# %% [markdown]
# ## Evaluate the accumulation of module end scaling over time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_time'
simulation_time = 200

# create the input file
ross.define_general(database_selection, quantity_of_modules = quantity_of_modules)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
time_data = ross.process_selected_output()
display(time_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 23:15:55.868624 local time.
#          Gypsum (mol)
# Time (s)
# 1.026E2      4.577E-2
# 1.066E2      4.888E-2
# 1.105E2      5.200E-2
# 1.144E2      5.512E-2
# 1.184E2      5.825E-2
# 1.223E2      6.137E-2
# 1.263E2      6.450E-2
# 1.302E2      6.764E-2
# 1.342E2      7.077E-2
# 1.381E2      7.390E-2
# 1.421E2      7.704E-2
# 1.460E2      8.018E-2
# 1.500E2      8.331E-2
# 1.539E2      8.645E-2
# 1.579E2      8.959E-2
# 1.618E2      9.273E-2
# 1.657E2      9.586E-2
# 1.697E2      9.900E-2
# 1.736E2      1.021E-1
# 1.776E2      1.053E-1
# 1.815E2      1.084E-1
# 1.855E2      1.116E-1
# 1.894E2      1.147E-1
# 1.934E2      1.178E-1
# 1.973E2      1.210E-1
# 2.013E2      1.241E-1
# 4.736E1      2.095E-3
# 5.130E1      5.240E-3
# 5.525E1      8.382E-3
# 5.919E1      1.152E-2
# 6.314E1      1.466E-2
# 6.709E1      1.778E-2
# 7.103E1      2.091E-2
# 7.498E1      2.402E-2
# 7.893E1      2.713E-2
# 8.287E1      3.024E-2
# 8.682E1      3.334E-2
# 9.077E1      3.645E-2
# 9.471E1      3.955E-2
# 9.866E1      4.266E-2

# %% [markdown]
# ## Evaluate scaling over a custom, high permeate, module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_distance'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_day': 300}

# create the input file
ross.define_general(database_selection)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
high_permeate_distance_data = ross.process_selected_output()
display(high_permeate_distance_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 23:16:02.177591 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Celestite (g/m^2) Goergeyite (g/m^2)  \
# Distance (m)
# 1.27E-1              0.00E0            0.00E0             0.00E0
# 2.12E-1              0.00E0            0.00E0             0.00E0
# 2.96E-1              0.00E0            0.00E0             6.33E0
# 3.81E-1              0.00E0            0.00E0             7.51E1
# 4.66E-1              0.00E0            0.00E0             7.44E1
# 5.50E-1             3.71E-4           4.66E-1             7.35E1
# 6.35E-1             6.66E-4           6.59E-1             7.26E1
# 7.20E-1             6.58E-4           6.61E-1             7.18E1
# 8.04E-1             6.39E-4           6.60E-1             7.06E1
# 8.89E-1             5.96E-4           6.47E-1             6.82E1
#
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              7.40E1
# 2.12E-1              7.28E1
# 2.96E-1              6.53E1
# 3.81E-1              0.00E0
# 4.66E-1              0.00E0
# 5.50E-1              0.00E0
# 6.35E-1              0.00E0
# 7.20E-1              0.00E0
# 8.04E-1              0.00E0
# 8.89E-1              0.00E0

# %% [markdown]
# ## Evaluate the accumulation of scaling at the end of the high permeate module over time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_time'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_day': 300}

# create the input file
ross.define_general(database_selection)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
high_permeate_time_data = ross.process_selected_output()
display(high_permeate_time_data)
# Out:
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-27 23:16:10.014782 local time.
#          Barite (mol) Celestite (mol) Goergeyite (mol)
# Time (s)
# 1.026E2      2.447E-6        3.633E-3         8.198E-2
# 1.066E2      2.613E-6        3.882E-3         8.755E-2
# 1.105E2      2.778E-6        4.130E-3         9.312E-2
# 1.144E2      2.943E-6        4.379E-3         9.868E-2
# 1.184E2      3.108E-6        4.627E-3         1.043E-1
# 1.223E2      3.273E-6        4.876E-3         1.098E-1
# 1.263E2      3.439E-6        5.124E-3         1.154E-1
# 1.302E2      3.604E-6        5.373E-3         1.209E-1
# 1.342E2      3.769E-6        5.621E-3         1.265E-1
# 1.381E2      3.934E-6        5.870E-3         1.321E-1
# 1.421E2      4.100E-6        6.118E-3         1.376E-1
# 1.460E2      4.265E-6        6.367E-3         1.432E-1
# 1.500E2      4.430E-6        6.616E-3         1.488E-1
# 1.539E2      4.595E-6        6.864E-3         1.543E-1
# 1.579E2      4.761E-6        7.113E-3         1.599E-1
# 1.618E2      4.926E-6        7.361E-3         1.655E-1
# 1.657E2      5.091E-6        7.610E-3         1.710E-1
# 1.697E2      5.256E-6        7.858E-3         1.766E-1
# 1.736E2      5.422E-6        8.107E-3         1.822E-1
# 1.776E2      5.587E-6        8.356E-3         1.877E-1
# 1.815E2      5.752E-6        8.604E-3         1.933E-1
# 1.855E2      5.917E-6        8.853E-3         1.988E-1
# 1.894E2      6.083E-6        9.101E-3         2.044E-1
# 1.934E2      6.248E-6        9.350E-3         2.100E-1
# 1.973E2      6.413E-6        9.599E-3         2.155E-1
# 2.013E2      6.579E-6        9.847E-3         2.211E-1
# 4.736E1      1.159E-7        1.674E-4         3.795E-3
# 5.130E1      2.834E-7        4.144E-4         9.391E-3
# 5.525E1      4.510E-7        6.614E-4         1.498E-2
# 5.919E1      6.184E-7        9.084E-4         2.058E-2
# 6.314E1      7.858E-7        1.155E-3         2.617E-2
# 6.709E1      9.529E-7        1.403E-3         3.175E-2
# 7.103E1      1.120E-6        1.650E-3         3.734E-2
# 7.498E1      1.287E-6        1.897E-3         4.293E-2
# 7.893E1      1.453E-6        2.145E-3         4.852E-2
# 8.287E1      1.619E-6        2.393E-3         5.410E-2
# 8.682E1      1.785E-6        2.641E-3         5.968E-2
# 9.077E1      1.951E-6        2.889E-3         6.526E-2
# 9.471E1      2.116E-6        3.137E-3         7.084E-2
# 9.866E1      2.282E-6        3.385E-3         7.641E-2
