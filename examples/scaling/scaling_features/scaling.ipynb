# %% [markdown]
# # Red Sea scaling through BW30-400

# %% [markdown]
# ## Evaluate scaling along the module at the final time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200
simulation_name = 'normal'

# create the input file
ross = ROSSPkg(database_selection, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute and process the input file
display(ross.processed_data)
# Out:
# --> The Zn element is not accepted by the pitzer database
#
# --> The Ni element is not accepted by the pitzer database
#
# --> The Cu element is not accepted by the pitzer database
#
# --> The Cd element is not accepted by the pitzer database
#
# --> The Co element is not accepted by the pitzer database
#
# --> The Pb element is not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 01:59:46.563401 local time.
# run_time (s): 5.971361599999
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             1.96E-2
# 5.50E-1              8.13E0
# 6.35E-1              8.00E0
# 7.20E-1              7.76E0
# 8.04E-1              7.51E0
# 8.89E-1              7.27E0

# %% [markdown]
# ## Evaluate the accumulation of module end scaling over time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_time'
simulation_time = 200
simulation_name = 'module-end'

# create the input file
ross = ROSSPkg(database_selection, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute and process the input file
display(ross.processed_data)
# Out:
# --> The Zn element is not accepted by the pitzer database
#
# --> The Ni element is not accepted by the pitzer database
#
# --> The Cu element is not accepted by the pitzer database
#
# --> The Cd element is not accepted by the pitzer database
#
# --> The Co element is not accepted by the pitzer database
#
# --> The Pb element is not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 02:00:08.425460 local time.
# run_time (s): 5.97757669999919
#          Gypsum (g/m^2)
# Time (s)
# 1.026E2         2.594E0
# 1.066E2         2.770E0
# 1.105E2         2.947E0
# 1.144E2         3.124E0
# 1.184E2         3.301E0
# 1.223E2         3.478E0
# 1.263E2         3.656E0
# 1.302E2         3.833E0
# 1.342E2         4.011E0
# 1.381E2         4.188E0
# 1.421E2         4.366E0
# 1.460E2         4.544E0
# 1.500E2         4.721E0
# 1.539E2         4.899E0
# 1.579E2         5.077E0
# 1.618E2         5.255E0
# 1.657E2         5.433E0
# 1.697E2         5.610E0
# 1.736E2         5.788E0
# 1.776E2         5.966E0
# 1.815E2         6.144E0
# 1.855E2         6.322E0
# 1.894E2         6.500E0
# 1.934E2         6.677E0
# 1.973E2         6.855E0
# 2.013E2         7.033E0
# 4.736E1        1.187E-1
# 5.130E1        2.969E-1
# 5.525E1        4.750E-1
# 5.919E1        6.528E-1
# 6.314E1        8.305E-1
# 6.709E1         1.008E0
# 7.103E1         1.185E0
# 7.498E1         1.361E0
# 7.893E1         1.538E0
# 8.287E1         1.714E0
# 8.682E1         1.890E0
# 9.077E1         2.066E0
# 9.471E1         2.241E0
# 9.866E1         2.418E0

# %% [markdown]
# ## Evaluate scaling over a custom, high permeate, module at the final time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_distance'
simulation_name = 'high-permeate'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_hour': 12.5}

# create the input file
ross = ROSSPkg(database_selection, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective, None, module_characteristics)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute and process the input file
display(ross.processed_data)
# Out:
# --> The Zn element is not accepted by the pitzer database
#
# --> The Ni element is not accepted by the pitzer database
#
# --> The Cu element is not accepted by the pitzer database
#
# --> The Cd element is not accepted by the pitzer database
#
# --> The Co element is not accepted by the pitzer database
#
# --> The Pb element is not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 02:00:36.751861 local time.
# run_time (s): 7.740958599999431
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Celestite (g/m^2) Goergeyite (g/m^2)  \
# Distance (m)
# 1.27E-1              0.00E0            0.00E0             0.00E0
# 2.12E-1              0.00E0            0.00E0             0.00E0
# 2.96E-1              0.00E0            0.00E0             2.32E0
# 3.81E-1              0.00E0            0.00E0             7.45E1
# 4.66E-1              0.00E0            0.00E0             7.41E1
# 5.50E-1             3.25E-4           4.17E-1             7.34E1
# 6.35E-1             6.55E-4           6.45E-1             7.27E1
# 7.20E-1             6.50E-4           6.49E-1             7.21E1
# 8.04E-1             6.34E-4           6.51E-1             7.12E1
# 8.89E-1             5.94E-4           6.41E-1             6.90E1
#
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              7.30E1
# 2.12E-1              7.20E1
# 2.96E-1              6.87E1
# 3.81E-1              0.00E0
# 4.66E-1              0.00E0
# 5.50E-1              0.00E0
# 6.35E-1              0.00E0
# 7.20E-1              0.00E0
# 8.04E-1              0.00E0
# 8.89E-1              0.00E0

# %% [markdown]
# ## Evaluate the accumulation of scaling at the end of the high permeate module over time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_time'
simulation_name = 'high-permeate_module-end'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_hour': 12.5}

# create the input file
ross = ROSSPkg(database_selection, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective, None, module_characteristics)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute and process the input file
display(ross.processed_data)
# Out:
# --> The Zn element is not accepted by the pitzer database
#
# --> The Ni element is not accepted by the pitzer database
#
# --> The Cu element is not accepted by the pitzer database
#
# --> The Cd element is not accepted by the pitzer database
#
# --> The Co element is not accepted by the pitzer database
#
# --> The Pb element is not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 02:00:59.147986 local time.
# run_time (s): 7.754714099999546
#          Barite (g/m^2) Celestite (g/m^2) Goergeyite (g/m^2)
# Time (s)
# 1.026E2        1.889E-4          2.201E-1            2.362E1
# 1.066E2        2.017E-4          2.352E-1            2.522E1
# 1.105E2        2.145E-4          2.502E-1            2.683E1
# 1.144E2        2.272E-4          2.653E-1            2.843E1
# 1.184E2        2.400E-4          2.803E-1            3.003E1
# 1.223E2        2.527E-4          2.954E-1            3.163E1
# 1.263E2        2.655E-4          3.104E-1            3.323E1
# 1.302E2        2.782E-4          3.255E-1            3.483E1
# 1.342E2        2.910E-4          3.406E-1            3.644E1
# 1.381E2        3.038E-4          3.556E-1            3.804E1
# 1.421E2        3.165E-4          3.707E-1            3.964E1
# 1.460E2        3.293E-4          3.857E-1            4.124E1
# 1.500E2        3.420E-4          4.008E-1            4.284E1
# 1.539E2        3.548E-4          4.159E-1            4.444E1
# 1.579E2        3.675E-4          4.309E-1            4.604E1
# 1.618E2        3.803E-4          4.460E-1            4.764E1
# 1.657E2        3.931E-4          4.610E-1            4.925E1
# 1.697E2        4.058E-4          4.761E-1            5.085E1
# 1.736E2        4.186E-4          4.912E-1            5.245E1
# 1.776E2        4.313E-4          5.062E-1            5.405E1
# 1.815E2        4.441E-4          5.213E-1            5.565E1
# 1.855E2        4.569E-4          5.363E-1            5.725E1
# 1.894E2        4.696E-4          5.514E-1            5.885E1
# 1.934E2        4.824E-4          5.665E-1            6.046E1
# 1.973E2        4.951E-4          5.815E-1            6.206E1
# 2.013E2        5.079E-4          5.966E-1            6.366E1
# 4.736E1        8.940E-6          1.014E-2            1.094E0
# 5.130E1        2.188E-5          2.510E-2            2.709E0
# 5.525E1        3.481E-5          4.007E-2            4.323E0
# 5.919E1        4.774E-5          5.503E-2            5.937E0
# 6.314E1        6.066E-5          7.000E-2            7.549E0
# 6.709E1        7.357E-5          8.498E-2            9.161E0
# 7.103E1        8.645E-5          9.996E-2            1.077E1
# 7.498E1        9.932E-5          1.149E-1            1.238E1
# 7.893E1        1.122E-4          1.299E-1            1.399E1
# 8.287E1        1.250E-4          1.450E-1            1.560E1
# 8.682E1        1.378E-4          1.600E-1            1.720E1
# 9.077E1        1.506E-4          1.750E-1            1.881E1
# 9.471E1        1.634E-4          1.900E-1            2.041E1
# 9.866E1        1.762E-4          2.051E-1            2.202E1
