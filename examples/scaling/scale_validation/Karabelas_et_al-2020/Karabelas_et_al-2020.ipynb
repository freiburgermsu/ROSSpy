# %% [markdown]
# # Define the simulation parameters

# %%
# execute the ROSSpy simulation
# from rosspy import ROSSPkg 

# Define the feed conditions
water_selection = 'waterwater'
water_characteristics = {
    'element': {
        'Li': {
            'concentration (ppm)': 0.04
        },
        'Na': {
            'concentration (ppm)': 701
        },
        'Mg': {
            'concentration (ppm)': 96
        },
        'Ca': {
            'concentration (ppm)': 250
        }, 
        'K': {
            'concentration (ppm)': 34
        },
        'Mn': {
            'concentration (ppm)': 0.09
        }, 
        'Fe': {
            'concentration (ppm)': 9.8
        }, 
        'Co': {
            'concentration (ppm)': 0.13
        }, 
        'Cu': {
            'concentration (ppm)': 0.03
        }, 
        'S(6)': {
            'concentration (ppm)': 433.8,
            'form': 'SO4'
        }, 
        'Cl': {
            'concentration (ppm)': 1400
        }, 
        'F': {
            'concentration (ppm)': 0.7
        },
        'N(5)': {
            'concentration (ppm)': 9.2,
            'form': 'NO3'
        },
        'Ba': {
            'concentration (ppm)': 0.05
        },
        'B': {
            'concentration (ppm)': 0.55
        },
        'Sr': {
            'concentration (ppm)': 6.2
        },
        'Si': {
            'concentration (ppm)': 26,
            'form': 'SiO2'
        },
        'C(4)': {
            'concentration (ppm)': 0.2,
            'form': 'CO3'
        },
    },
    'temperature': {
        'value': 31
    },
    'Alkalinity': {
        'value': 192.7,
        'form': 'HCO3'
    },
    'pH': {
        'value': 6.8
    },
}

# define the module characteristics
permeate_recovery = 0.68
module_characteristics = {
    'max_feed_flow_m3_per_hour':10.5,
    'permeate_flow_m3_per_hour': permeate_recovery*10.58,
    'active_m2': 37
}

# general parameters
simulation_perspective = 'all_distance'
simulation_time = 200

# %% [markdown]
# # Execution with all of the databases

# %%
from glob import glob
import os, re

# loop through the databases
# %run ../../../../rosspy/ro.py
ross = ROSSPkg(database_selection = 'pitzer')
for db in ross.databases:
    # create the input file    
    print('\n', db, 'database\n', '='*2*len(f'{db} database'))
    ross = ROSSPkg(db, printing = False)
    ross.reactive_transport(simulation_time, simulation_perspective, module_characteristics = module_characteristics)
    ross.feed_geochemistry(water_selection, water_characteristics)
    ross.execute(f'{db} scaling', plot_title = f'Scaling from wastewater, via the {db} database')
    display(ross.processed_data)
# Out:
#  Amm database
#  ========================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the Amm database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:06.728125 local time.
# run_time (s): 2.6461841999553144
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          9.74E-2        9.62E-4
# 2.12E-1               0.00E0          9.22E-2        9.06E-4
# 2.96E-1               0.00E0          8.70E-2        8.51E-4
# 3.81E-1               0.00E0          8.19E-2        7.99E-4
# 4.66E-1               0.00E0          7.68E-2        7.48E-4
# 5.50E-1               0.00E0          7.18E-2        7.00E-4
# 6.35E-1               0.00E0          6.68E-2        6.53E-4
# 7.20E-1              6.18E-1          2.11E-2        6.15E-4
# 8.04E-1              9.35E-1          2.29E-3        5.74E-4
# 8.89E-1              9.92E-1          2.21E-3        5.30E-4
#  ColdChem database
#  ==================================
#
# --> The ['Li', 'Mn', 'Fe', 'Co', 'Cu', 'F', 'N(5)', 'Ba', 'B', 'Sr', 'Si', 'C(4)'] elements are not accepted by the ColdChem database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:09.481483 local time.
# run_time (s): 1.3383989003486931
# No scaling occurred.
# None
#  core10 database
#  ==============================
#
# --> The ['S(6)', 'F', 'N(5)', 'Ba', 'Sr', 'C(4)'] elements are not accepted by the core10 database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:10.845648 local time.
# run_time (s): 4.907338900025934
#              Dolomite (g/m^2) Siderite (g/m^2)
# Distance (m)
# 1.27E-1               4.56E-1          9.70E-3
# 2.12E-1               4.60E-1          9.50E-3
# 2.96E-1               4.64E-1          9.26E-3
# 3.81E-1               4.69E-1          8.97E-3
# 4.66E-1               4.73E-1          8.62E-3
# 5.50E-1               4.78E-1          8.19E-3
# 6.35E-1               4.84E-1          7.66E-3
# 7.20E-1               4.90E-1          7.00E-3
# 8.04E-1               4.97E-1          6.16E-3
# 8.89E-1               5.06E-1          5.08E-3
#  frezchem database
#  ==================================
#
# --> The ['Li', 'Mn', 'Fe', 'Co', 'Cu', 'F', 'N(5)', 'Ba', 'B', 'Sr', 'Si'] elements are not accepted by the frezchem database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:15.857921 local time.
# run_time (s): 1.8548590997233987
#              Hydromagnesite (g/m^2)
# Distance (m)
# 1.27E-1                     2.02E-3
# 2.12E-1                     1.81E-3
# 2.96E-1                     1.61E-3
# 3.81E-1                     1.43E-3
# 4.66E-1                     1.26E-3
# 5.50E-1                     1.11E-3
# 6.35E-1                     9.65E-4
# 7.20E-1                     8.35E-4
# 8.04E-1                     7.16E-4
# 8.89E-1                     6.08E-4
#  iso database
#  ========================
#
# --> The ['Li', 'Mn', 'Co', 'Cu', 'N(5)', 'Ba', 'B', 'Sr'] elements are not accepted by the iso database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:17.816591 local time.
# run_time (s): 4.074439599644393
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0
# 2.12E-1               0.00E0
# 2.96E-1               0.00E0
# 3.81E-1               0.00E0
# 4.66E-1               0.00E0
# 5.50E-1               0.00E0
# 6.35E-1               0.00E0
# 7.20E-1               0.00E0
# 8.04E-1               0.00E0
# 8.89E-1               0.00E0
#  llnl database
#  ==========================
#
# --> The ['S(6)', 'N(5)', 'C(4)'] elements are not accepted by the llnl database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:21.996155 local time.
# run_time (s): 9.689592699985951
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Dolomite (g/m^2) Witherite (g/m^2)
# Distance (m)
# 1.27E-1               4.29E-1           9.27E-6
# 2.12E-1               4.34E-1           7.77E-6
# 2.96E-1               4.38E-1           6.01E-6
# 3.81E-1               4.42E-1           3.94E-6
# 4.66E-1               4.47E-1           1.47E-6
# 5.50E-1               4.52E-1            0.00E0
# 6.35E-1               4.57E-1            0.00E0
# 7.20E-1               4.64E-1            0.00E0
# 8.04E-1               4.71E-1            0.00E0
# 8.89E-1               4.79E-1            0.00E0
#  minteq database
#  ==============================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the minteq database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:31.805460 local time.
# run_time (s): 4.934731499757618
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Calcite (g/m^2) Ferrihydrite (g/m^2)  \
# Distance (m)
# 1.27E-1             5.71E-4          0.00E0              1.98E-5
# 2.12E-1             5.35E-4          0.00E0              1.98E-5
# 2.96E-1             5.00E-4          0.00E0              1.98E-5
# 3.81E-1             4.67E-4          0.00E0              1.97E-5
# 4.66E-1             4.35E-4          0.00E0              1.97E-5
# 5.50E-1             4.04E-4          0.00E0              1.96E-5
# 6.35E-1             3.76E-4         1.90E-1              1.41E-5
# 7.20E-1             3.53E-4         9.05E-1               0.00E0
# 8.04E-1             3.24E-4         9.54E-1               0.00E0
# 8.89E-1             2.97E-4          1.01E0               0.00E0
#
#              Siderite (g/m^2)
# Distance (m)
# 1.27E-1               1.65E-1
# 2.12E-1               1.58E-1
# 2.96E-1               1.50E-1
# 3.81E-1               1.43E-1
# 4.66E-1               1.35E-1
# 5.50E-1               1.27E-1
# 6.35E-1               9.54E-2
# 7.20E-1               6.07E-3
# 8.04E-1               5.93E-3
# 8.89E-1               5.63E-3
#  minteq.v4 database
#  ====================================
#
# --> The [] elements are not accepted by the minteq.v4 database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:36.892806 local time.
# run_time (s): 6.224908399861306
#              Ferrihydrite (g/m^2) Brucite (g/m^2) Atacamite (g/m^2)  \
# Distance (m)
# 1.27E-1                   4.31E-6         4.17E-2           3.78E-4
# 2.12E-1                   4.07E-6         4.01E-2           3.47E-4
# 2.96E-1                   3.84E-6         3.86E-2           3.18E-4
# 3.81E-1                   3.61E-6         3.72E-2           2.90E-4
# 4.66E-1                   3.39E-6         3.58E-2           2.63E-4
# 5.50E-1                   3.17E-6         3.46E-2           2.38E-4
# 6.35E-1                   2.96E-6         3.34E-2           2.13E-4
# 7.20E-1                   2.75E-6         3.24E-2           1.90E-4
# 8.04E-1                   2.55E-6         3.15E-2           1.68E-4
# 8.89E-1                   2.35E-6         3.09E-2           1.47E-4
#
#              Barite (g/m^2)
# Distance (m)
# 1.27E-1             5.55E-4
# 2.12E-1             5.20E-4
# 2.96E-1             4.87E-4
# 3.81E-1             4.54E-4
# 4.66E-1             4.23E-4
# 5.50E-1             3.94E-4
# 6.35E-1             3.65E-4
# 7.20E-1             3.38E-4
# 8.04E-1             3.12E-4
# 8.89E-1             2.86E-4
#  phreeqc database
#  ================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the phreeqc database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:43.362312 local time.
# run_time (s): 2.6169537999667227
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          9.74E-2        9.62E-4
# 2.12E-1               0.00E0          9.22E-2        9.06E-4
# 2.96E-1               0.00E0          8.70E-2        8.51E-4
# 3.81E-1               0.00E0          8.19E-2        7.99E-4
# 4.66E-1               0.00E0          7.68E-2        7.48E-4
# 5.50E-1               0.00E0          7.18E-2        7.00E-4
# 6.35E-1               0.00E0          6.68E-2        6.53E-4
# 7.20E-1              6.18E-1          2.11E-2        6.15E-4
# 8.04E-1              9.35E-1          2.29E-3        5.74E-4
# 8.89E-1              9.92E-1          2.21E-3        5.30E-4
#  pitzer database
#  ==============================
#
# --> The ['Co', 'Cu', 'F', 'N(5)'] elements are not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:27:46.085645 local time.
# run_time (s): 4.550303500145674
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Brucite (g/m^2) Calcite (g/m^2)
# Distance (m)
# 1.27E-1             7.24E-4         4.74E-2          0.00E0
# 2.12E-1             6.78E-4         4.52E-2          0.00E0
# 2.96E-1             6.34E-4         4.31E-2          0.00E0
# 3.81E-1             5.91E-4         4.11E-2          0.00E0
# 4.66E-1             5.51E-4         3.91E-2          0.00E0
# 5.50E-1             5.11E-4         3.71E-2          0.00E0
# 6.35E-1             4.74E-4         3.53E-2          0.00E0
# 7.20E-1             4.38E-4         3.35E-2          0.00E0
# 8.04E-1             4.04E-4         3.17E-2          0.00E0
# 8.89E-1             3.71E-4         2.95E-2         6.58E-3
#  sit database
#  ========================
#
# --> The ['S(6)', 'N(5)', 'C(4)'] elements are not accepted by the sit database
#
# Estimated completion in 54.9 seconds: 2022-03-03 23:28:37.851544 local time.
# run_time (s): 27.416709600016475
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Ferryhydrite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0               0.00E0
# 2.12E-1               0.00E0               0.00E0
# 2.96E-1               0.00E0               0.00E0
# 3.81E-1               0.00E0               0.00E0
# 4.66E-1               0.00E0               0.00E0
# 5.50E-1               0.00E0               0.00E0
# 6.35E-1               0.00E0               0.00E0
# 7.20E-1              6.13E-1               0.00E0
# 8.04E-1              8.53E-1               0.00E0
# 8.89E-1              9.05E-1               0.00E0
#  Tipping_Hurley database
#  ==============================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the Tipping_Hurley database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:28:18.331223 local time.
# run_time (s): 4.615674499887973
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          9.72E-2        7.14E-4
# 2.12E-1               0.00E0          9.21E-2        6.72E-4
# 2.96E-1               0.00E0          8.69E-2        6.32E-4
# 3.81E-1               0.00E0          8.18E-2        5.92E-4
# 4.66E-1               0.00E0          7.67E-2        5.54E-4
# 5.50E-1               0.00E0          7.17E-2        5.18E-4
# 6.35E-1               0.00E0          6.67E-2        4.83E-4
# 7.20E-1              5.54E-1          2.55E-2        4.54E-4
# 8.04E-1              9.34E-1          2.37E-3        4.23E-4
# 8.89E-1              9.92E-1          2.29E-3        3.90E-4
#  wateq4f database
#  ================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the wateq4f database
#
# Estimated completion in 7.85 seconds: 2022-03-03 23:28:23.118302 local time.
# run_time (s): 4.602064599748701
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 1.27E-1               0.00E0          9.72E-2        7.14E-4
# 2.12E-1               0.00E0          9.21E-2        6.72E-4
# 2.96E-1               0.00E0          8.69E-2        6.32E-4
# 3.81E-1               0.00E0          8.18E-2        5.92E-4
# 4.66E-1               0.00E0          7.67E-2        5.54E-4
# 5.50E-1               0.00E0          7.17E-2        5.18E-4
# 6.35E-1               0.00E0          6.67E-2        4.83E-4
# 7.20E-1              5.54E-1          2.55E-2        4.54E-4
# 8.04E-1              9.34E-1          2.37E-3        4.23E-4
# 8.89E-1              9.92E-1          2.29E-3        3.90E-4
