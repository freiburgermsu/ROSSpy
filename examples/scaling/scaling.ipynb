# %% [markdown]
# # Red Sea scaling through BW30-400

# %% [markdown]
# ## Evaluate scaling along the module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
selected_output_path = 'Red Sea_BW30-400_PE=1_1.1'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction(quantity_of_modules)
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
# Out:
# Estimated completion in 22.0 seconds by 2021-10-15 20:32:39.670836 local time.

# %% [markdown]
# ## View the data

# %%
display(scaling_data)
# Out:
#              Gypsum
# Distance (m)
# 0.127 m        0.00
# 0.212 m        0.00
# 0.296 m        0.00
# 0.381 m        0.00
# 0.466 m       0.439
# 0.550 m        8.21
# 0.635 m        7.98
# 0.720 m        7.71
# 0.804 m        7.45
# 0.889 m        7.19

# %% [markdown]
# ## Evaluate the accumulation of module end scaling over time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_time'
selected_output_path = 'Red Sea_BW30-400_PE=1_1.1'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction(quantity_of_modules)
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
# Out:
# Estimated completion in 22.0 seconds by 2021-10-15 20:32:46.788815 local time.

# %% [markdown]
# ## View the data

# %%
display(scaling_data)
# Out:
#          Gypsum (mol)
# Time (s)
# 102.6         0.04577
# 106.6         0.04888
# 110.5         0.05200
# 114.4         0.05512
# 118.4         0.05825
# 122.3         0.06137
# 126.3         0.06450
# 130.2         0.06764
# 134.2         0.07077
# 138.1         0.07390
# 142.1         0.07704
# 146.0         0.08018
# 150.0         0.08331
# 153.9         0.08645
# 157.9         0.08959
# 161.8         0.09273
# 165.7         0.09586
# 169.7         0.09900
# 173.6          0.1021
# 177.6          0.1053
# 181.5          0.1084
# 185.5          0.1116
# 189.4          0.1147
# 193.4          0.1178
# 197.3          0.1210
# 201.3          0.1241
# 47.36        2.095e-3
# 51.30        5.240e-3
# 55.25        8.382e-3
# 59.19         0.01152
# 63.14         0.01466
# 67.09         0.01778
# 71.03         0.02091
# 74.98         0.02402
# 78.93         0.02713
# 82.87         0.03024
# 86.82         0.03334
# 90.77         0.03645
# 94.71         0.03955
# 98.66         0.04266

# %% [markdown]
# ## Evaluate scaling over a custom, high permeate, module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
selected_output_path = 'Red Sea_BW30-400_PE=1_1.1'
simulation_time = 200
simulation_perspective = 'all_distance'

# custom module parameterization
module_characteristics = {
    'permeate_flow_m3_per_day': 300
}

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
# Out:
# Estimated completion in 22.0 seconds by 2021-10-15 20:32:52.800165 local time.

# %% [markdown]
# ## View the data

# %%
display(scaling_data)
# Out:
#                Barite Celestite Goergeyite Gypsum
# Distance (m)
# 0.127 m           0.0      0.00       0.00   74.0
# 0.212 m           0.0      0.00       0.00   72.8
# 0.296 m           0.0      0.00       6.33   65.3
# 0.381 m           0.0      0.00       75.1   0.00
# 0.466 m           0.0      0.00       74.4   0.00
# 0.550 m       3.71e-4     0.466       73.5   0.00
# 0.635 m       6.66e-4     0.659       72.6   0.00
# 0.720 m       6.58e-4     0.661       71.8   0.00
# 0.804 m       6.39e-4     0.660       70.6   0.00
# 0.889 m       5.96e-4     0.647       68.2   0.00

# %% [markdown]
# ## Evaluate the accumulation of scaling at the end of the high permeate module over time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
selected_output_path = 'Red Sea_BW30-400_PE=1_1.1'
simulation_time = 200
simulation_perspective = 'all_time'

# custom module parameterization
module_characteristics = {
    'permeate_flow_m3_per_day': 300
}

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
# Out:
# Estimated completion in 22.0 seconds by 2021-10-15 20:33:00.287425 local time.

# %% [markdown]
# # view the data

# %%
display(scaling_data)
# Out:
#          Barite (mol) Celestite (mol) Goergeyite (mol)
# Time (s)
# 102.6        2.447e-6        3.633e-3          0.08198
# 106.6        2.613e-6        3.882e-3          0.08755
# 110.5        2.778e-6        4.130e-3          0.09312
# 114.4        2.943e-6        4.379e-3          0.09868
# 118.4        3.108e-6        4.627e-3           0.1043
# 122.3        3.273e-6        4.876e-3           0.1098
# 126.3        3.439e-6        5.124e-3           0.1154
# 130.2        3.604e-6        5.373e-3           0.1209
# 134.2        3.769e-6        5.621e-3           0.1265
# 138.1        3.934e-6        5.870e-3           0.1321
# 142.1        4.100e-6        6.118e-3           0.1376
# 146.0        4.265e-6        6.367e-3           0.1432
# 150.0        4.430e-6        6.616e-3           0.1488
# 153.9        4.595e-6        6.864e-3           0.1543
# 157.9        4.761e-6        7.113e-3           0.1599
# 161.8        4.926e-6        7.361e-3           0.1655
# 165.7        5.091e-6        7.610e-3           0.1710
# 169.7        5.256e-6        7.858e-3           0.1766
# 173.6        5.422e-6        8.107e-3           0.1822
# 177.6        5.587e-6        8.356e-3           0.1877
# 181.5        5.752e-6        8.604e-3           0.1933
# 185.5        5.917e-6        8.853e-3           0.1988
# 189.4        6.083e-6        9.101e-3           0.2044
# 193.4        6.248e-6        9.350e-3           0.2100
# 197.3        6.413e-6        9.599e-3           0.2155
# 201.3        6.579e-6        9.847e-3           0.2211
# 47.36        1.159e-7        1.674e-4         3.795e-3
# 51.30        2.834e-7        4.144e-4         9.391e-3
# 55.25        4.510e-7        6.614e-4          0.01498
# 59.19        6.184e-7        9.084e-4          0.02058
# 63.14        7.858e-7        1.155e-3          0.02617
# 67.09        9.529e-7        1.403e-3          0.03175
# 71.03        1.120e-6        1.650e-3          0.03734
# 74.98        1.287e-6        1.897e-3          0.04293
# 78.93        1.453e-6        2.145e-3          0.04852
# 82.87        1.619e-6        2.393e-3          0.05410
# 86.82        1.785e-6        2.641e-3          0.05968
# 90.77        1.951e-6        2.889e-3          0.06526
# 94.71        2.116e-6        3.137e-3          0.07084
# 98.66        2.282e-6        3.385e-3          0.07641
