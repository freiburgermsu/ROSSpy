# %% [markdown]
# # Scaling with all of the databases

# %%
# %matplotlib inline
# %run ../../../rosspy/ro.py
# import rosspy

# simulate the databases
ross = ROSSPkg('pitzer')
for db in ross.databases:
    print('='*30, f'\n\n{db} database \n', '='*(len(db)+10))
    export_name = f'{db} database'

    # define the simulation
    ross = ROSSPkg(db)
    ross.reactive_transport(simulation_time = 200)
    ross.feed_geochemistry('red_sea')
    
    # execute and process the input file
    try:
        ross.execute(export_name, figure_title = f'Scaling in the {water_selection} via the {db} database')
        scaling_data = ross.processed_data
    except:
        print(f'\n\n--> ERROR: The simulation with the {db} database failed to converge\n\n')
        scaling_data = None
        
    display(scaling_data)
# Out:
# ==============================
#
# Amm database
#  =============
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Ni', 'Co'] elements are not accepted by the Amm database
#
# Estimated completion in 7 seconds: 2022-04-08 15:08:38.055325 local time.
# run_time (s): 4.9339913000003435
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '172.2'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 21.422648295997536,
#                                 'H': 1.0775360109520313,
#                                 'O': 42.76030729414928,
#                                 'S': 17.139508398901164}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 2.376250065842445,
#                                'H': 0.11952280509831999,
#                                'O': 4.7430729207345195,
#                                'S': 1.9011542083247166}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 2.319053674760898,
#                                'H': 0.11664588856422474,
#                                'O': 4.628907051745285,
#                                'S': 1.855393384929592}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 2.2644571196376035,
#                                'H': 0.11389974096349749,
#                                'O': 4.5199305404373815,
#                                'S': 1.8117125989615188}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 2.209860564514309,
#                                'H': 0.11115359336277021,
#                                'O': 4.410954029129476,
#                                'S': 1.7680318129934454}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 2.1526641734327616,
#                                'H': 0.10827667682867498,
#                                'O': 4.296788160140243,
#                                'S': 1.7222709895983206}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.1006674542677195,
#                               'H': 0.10566129816131568,
#                               'O': 4.193001006513667,
#                               'S': 1.6806702410572987}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.046070899144425,
#                                'H': 0.10291515056058842,
#                                'O': 4.084024495205762,
#                                'S': 1.6369894550892252}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 1.9940741799793822,
#                               'H': 0.10029977189322913,
#                               'O': 3.980237341579186,
#                               'S': 1.5953887065482029}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 1.9394776248560874,
#                                'H': 0.09755362429250186,
#                                'O': 3.8712608302712814,
#                                'S': 1.5517079205801296}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.8874809056910449,
#                                'H': 0.09493824562514255,
#                                'O': 3.7674736766447054,
#                                'S': 1.5101071720391073}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.8380840224842545,
#                                'H': 0.09245363589115123,
#                                'O': 3.6688758806994586,
#                                'S': 1.4705864609251362}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             8.240E1
# 1.27E-1             9.140E0
# 2.12E-1             8.920E0
# 2.96E-1             8.710E0
# 3.81E-1             8.500E0
# 4.66E-1             8.280E0
# 5.50E-1             8.080E0
# 6.35E-1             7.870E0
# 7.20E-1             7.670E0
# 8.04E-1             7.460E0
# 8.89E-1             7.260E0
# 9.74E-1             7.070E0
# ==============================
#
# ColdChem database
#  ==================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Mn', 'Fe', 'B', 'Sr', 'Ba', 'Li', 'Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the ColdChem database
#
# Estimated completion in 7 seconds: 2022-04-08 15:08:43.510961 local time.
# run_time (s): 2.7827866999869
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '172.2'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 1.318116830833829,
#                                'H': 0.06629984921755824,
#                                'O': 2.6310043444336997,
#                                'S': 1.054578975514914}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 2.1266658138502406,
#                                'H': 0.10696898749499534,
#                                'O': 4.244894583326954,
#                                'S': 1.7014706153278096}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 2.072069258726946,
#                                'H': 0.10422283989426807,
#                                'O': 4.13591807201905,
#                                'S': 1.6577898293597364}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             0.000E0
# 1.27E-1             0.000E0
# 2.12E-1             0.000E0
# 2.96E-1             0.000E0
# 3.81E-1             0.000E0
# 4.66E-1             0.000E0
# 5.50E-1             0.000E0
# 6.35E-1             0.000E0
# 7.20E-1             0.000E0
# 8.04E-1             5.070E0
# 8.89E-1             8.180E0
# 9.74E-1             7.970E0
# ==============================
#
# core10 database
#  ================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['S(6)', 'Sr', 'Ba', 'Cd', 'Pb'] elements are not accepted by the core10 database
#
# Estimated completion in 7 seconds: 2022-04-08 15:08:46.480398 local time.
# run_time (s): 7.668748599986429
# No scaling occurred.
# None
# ==============================
#
# frezchem database
#  ==================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Mn', 'Fe', 'B', 'Sr', 'Ba', 'Li', 'Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the frezchem database
#
# Estimated completion in 7 seconds: 2022-04-08 15:08:54.181296 local time.
# run_time (s): 3.695906200009631
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '172.2'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 7.12355052561083,
#                                 'H': 0.358306877428224,
#                                 'O': 14.2188400468409,
#                                 'S': 5.699302550120047}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 2.352851542218176,
#                                'H': 0.1183458846980083,
#                                'O': 4.696368701602561,
#                                'S': 1.8824338714812565}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 2.3008548230531334,
#                                'H': 0.11573050603064898,
#                                'O': 4.592581547975984,
#                                'S': 1.8408331229402342}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 2.246258267929839,
#                                'H': 0.11298435842992173,
#                                'O': 4.48360503666808,
#                                'S': 1.797152336972161}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 2.191661712806544,
#                                'H': 0.11023821082919445,
#                                'O': 4.374628525360174,
#                                'S': 1.7534715510040875}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 2.1396649936415013,
#                                'H': 0.10762283216183517,
#                                'O': 4.270841371733599,
#                                'S': 1.7118708024630653}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.0876682744764588,
#                               'H': 0.10500745349447585,
#                               'O': 4.1670542181070225,
#                               'S': 1.670270053922043}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.035671555311416,
#                                'H': 0.10239207482711657,
#                                'O': 4.063267064480447,
#                                'S': 1.6286693053810208}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 1.9862746721046256,
#                               'H': 0.09990746509312523,
#                               'O': 3.9646692685351996,
#                               'S': 1.5891485942670496}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 1.9342779529395833,
#                                'H': 0.09729208642576594,
#                                'O': 3.860882114908624,
#                                'S': 1.5475478457260274}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.884881069732793,
#                                'H': 0.0948074766917746,
#                                'O': 3.762284318963377,
#                                'S': 1.5080271346120562}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.8354841865260023,
#                                'H': 0.09232286695778326,
#                                'O': 3.6636865230181295,
#                                'S': 1.4685064234980851}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             2.740E1
# 1.27E-1             9.050E0
# 2.12E-1             8.850E0
# 2.96E-1             8.640E0
# 3.81E-1             8.430E0
# 4.66E-1             8.230E0
# 5.50E-1             8.030E0
# 6.35E-1             7.830E0
# 7.20E-1             7.640E0
# 8.04E-1             7.440E0
# 8.89E-1             7.250E0
# 9.74E-1             7.060E0
# ==============================
#
# iso database
#  =============
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Mn', 'B', 'Sr', 'Ba', 'Li', 'Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the iso database
#
# Estimated completion in 7 seconds: 2022-04-08 15:08:58.070867 local time.
# run_time (s): 2.8805859999993118
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '172.2'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 24.672443243812697,
#                                 'H': 1.2409971776619875,
#                                 'O': 49.24700439581027,
#                                 'S': 19.739555182715055}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 2.5062418637550516,
#                                'H': 0.12606125176671823,
#                                'O': 5.002540804800959,
#                                'S': 2.0051560796772723}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 2.4464456367152523,
#                                'H': 0.12305356629925503,
#                                'O': 4.883185578130397,
#                                'S': 1.9573152188550966}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 2.3866494096754534,
#                                'H': 0.12004588083179182,
#                                'O': 4.763830351459834,
#                                'S': 1.9094743580329208}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 2.329453018593907,
#                                'H': 0.11716896429769662,
#                                'O': 4.649664482470602,
#                                'S': 1.8637135346377967}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 2.27225662751236,
#                                'H': 0.11429204776360138,
#                                'O': 4.5354986134813675,
#                                'S': 1.817952711242672}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.215060236430813,
#                               'H': 0.11141513122950614,
#                               'O': 4.421332744492133,
#                               'S': 1.7721918878475473}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.1578638453492665,
#                                'H': 0.10853821469541093,
#                                'O': 4.307166875502901,
#                                'S': 1.7264310644524232}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 2.1032672902259715,
#                               'H': 0.10579206709468365,
#                               'O': 4.198190364194995,
#                               'S': 1.6827502784843498}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 2.048670735102677,
#                                'H': 0.10304591949395639,
#                                'O': 4.089213852887091,
#                                'S': 1.6390694925162763}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.9940741799793822,
#                                'H': 0.10029977189322913,
#                                'O': 3.980237341579186,
#                                'S': 1.5953887065482029}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.9394776248560874,
#                                'H': 0.09755362429250186,
#                                'O': 3.8712608302712814,
#                                'S': 1.5517079205801296}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             9.490E1
# 1.27E-1             9.640E0
# 2.12E-1             9.410E0
# 2.96E-1             9.180E0
# 3.81E-1             8.960E0
# 4.66E-1             8.740E0
# 5.50E-1             8.520E0
# 6.35E-1             8.300E0
# 7.20E-1             8.090E0
# 8.04E-1             7.880E0
# 8.89E-1             7.670E0
# 9.74E-1             7.460E0
# ==============================
#
# llnl database
#  ==============
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['S(6)'] elements are not accepted by the llnl database
#
# Estimated completion in 7 seconds: 2022-04-08 15:09:01.238377 local time.
#
#
# --> ERROR: The simulation with the llnl database failed to converge
# None
# ==============================
#
# minteq database
#  ================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Co'] elements are not accepted by the minteq database
#
# Estimated completion in 7 seconds: 2022-04-08 15:09:01.594764 local time.
# run_time (s): 8.308463499997742
# mineral Anhydrite   {'formula': 'CaSO4', 'mass': '140'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 55.63911133049215,
#                                 'O': 88.84599010140987,
#                                 'S': 44.514898568097976}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 2.0459884854334414,
#                                'O': 3.267087995792585,
#                                'S': 1.6369235187739732}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 1.9959427239192422,
#                                'O': 3.1871736131616872,
#                                'S': 1.5968836629190704}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 1.9488408307294076,
#                                'O': 3.111960076567901,
#                                'S': 1.559199092702691}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 1.8987950692152085,
#                                'O': 3.032045693937003,
#                                'S': 1.5191592368477882}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 1.8516931760253736,
#                                'O': 2.956832157343217,
#                                'S': 1.481474666631409}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 1.804591282835539,
#                               'O': 2.881618620749431,
#                               'S': 1.4437900964150296}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 1.7574893896457044,
#                                'O': 2.8064050841556445,
#                                'S': 1.4061055261986504}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 1.7103874964558696,
#                               'O': 2.7311915475618584,
#                               'S': 1.368420955982271}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 1.6662294715903998,
#                                'O': 2.6606788570051845,
#                                'S': 1.3330916714044156}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.6191275784005652,
#                                'O': 2.585465320411398,
#                                'S': 1.2954071011880364}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.5749695535350952,
#                                'O': 2.5149526298547236,
#                                'S': 1.2600778166101807}}}
#              Anhydrite (g/m^2)
# Distance (m)
# 4.23E-2                1.890E2
# 1.27E-1                6.950E0
# 2.12E-1                6.780E0
# 2.96E-1                6.620E0
# 3.81E-1                6.450E0
# 4.66E-1                6.290E0
# 5.50E-1                6.130E0
# 6.35E-1                5.970E0
# 7.20E-1                5.810E0
# 8.04E-1                5.660E0
# 8.89E-1                5.500E0
# 9.74E-1                5.350E0
# ==============================
#
# minteq.v4 database
#  ===================
# Effluent module 1 CF: 1.1177571260302372
#
# Estimated completion in 7 seconds: 2022-04-08 15:09:10.200469 local time.
#
#
# --> ERROR: The simulation with the minteq.v4 database failed to converge
# None
# ==============================
#
# phreeqc database
#  =================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Ni', 'Co'] elements are not accepted by the phreeqc database
#
# Estimated completion in 7 seconds: 2022-04-08 15:09:10.358607 local time.
# run_time (s): 3.794030599994585
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 21.162664700172325,
#                                 'H': 1.064459117615235,
#                                 'O': 42.2413715260164,
#                                 'S': 16.931504656196054}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 2.3476518703016716,
#                                'H': 0.11808434683127235,
#                                'O': 4.685989986239902,
#                                'S': 1.878273796627154}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 2.290455479220125,
#                                'H': 0.11520743029717714,
#                                'O': 4.571824117250669,
#                                'S': 1.8325129732320298}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 2.23585892409683,
#                                'H': 0.11246128269644987,
#                                'O': 4.462847605942764,
#                                'S': 1.7888321872639563}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 2.1812623689735355,
#                                'H': 0.10971513509572262,
#                                'O': 4.35387109463486,
#                                'S': 1.745151401295883}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 2.1266658138502406,
#                                'H': 0.10696898749499534,
#                                'O': 4.244894583326954,
#                                'S': 1.7014706153278096}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.072069258726946,
#                               'H': 0.10422283989426807,
#                               'O': 4.13591807201905,
#                               'S': 1.6577898293597364}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.0200725395619035,
#                                'H': 0.10160746122690877,
#                                'O': 4.032130918392474,
#                                'S': 1.616189080818714}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 1.968075820396861,
#                               'H': 0.09899208255954949,
#                               'O': 3.9283437647658985,
#                               'S': 1.574588332277692}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 1.9160791012318183,
#                                'H': 0.09637670389219018,
#                                'O': 3.8245566111393225,
#                                'S': 1.5329875837366695}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.8640823820667758,
#                                'H': 0.09376132522483088,
#                                'O': 3.7207694575127466,
#                                'S': 1.4913868351956474}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.8146854988599854,
#                                'H': 0.09127671549083954,
#                                'O': 3.6221716615674997,
#                                'S': 1.4518661240816764}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             8.140E1
# 1.27E-1             9.030E0
# 2.12E-1             8.810E0
# 2.96E-1             8.600E0
# 3.81E-1             8.390E0
# 4.66E-1             8.180E0
# 5.50E-1             7.970E0
# 6.35E-1             7.770E0
# 7.20E-1             7.570E0
# 8.04E-1             7.370E0
# 8.89E-1             7.170E0
# 9.74E-1             6.980E0
# ==============================
#
# pitzer database
#  ================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-08 15:09:14.406066 local time.
# run_time (s): 7.889729100003024
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 0.013701135499988713,
#                                'H': 0.0006891522788491753,
#                                'O': 0.027347914980602753,
#                                'S': 0.01096179724055936}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.1578638453492665,
#                               'H': 0.10853821469541093,
#                               'O': 4.307166875502901,
#                               'S': 1.7264310644524232}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.1292656498084925,
#                                'H': 0.1070997564283633,
#                                'O': 4.250083941008283,
#                                'S': 1.7035506527548607}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 2.0772689306434504,
#                               'H': 0.10448437776100401,
#                               'O': 4.146296787381708,
#                               'S': 1.6619499042138386}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 2.025272211478408,
#                                'H': 0.1018689990936447,
#                                'O': 4.042509633755132,
#                                'S': 1.6203491556728162}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.973275492313365,
#                                'H': 0.0992536204262854,
#                                'O': 3.938722480128556,
#                                'S': 1.578748407131794}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.9212787731483225,
#                                'H': 0.0966382417589261,
#                                'O': 3.83493532650198,
#                                'S': 1.5371476585907717}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             0.000E0
# 1.27E-1             0.000E0
# 2.12E-1             0.000E0
# 2.96E-1             0.000E0
# 3.81E-1             0.000E0
# 4.66E-1            5.270E-2
# 5.50E-1             8.300E0
# 6.35E-1             8.190E0
# 7.20E-1             7.990E0
# 8.04E-1             7.790E0
# 8.89E-1             7.590E0
# 9.74E-1             7.390E0
# ==============================
#
# sit database
#  =============
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['S(6)'] elements are not accepted by the sit database
#
# Estimated completion in 54 seconds: 2022-04-08 15:10:09.799052 local time.
# run_time (s): 61.8533524999948
# mineral Ferryhydrite   {'formula': 'Fe(OH)3', 'mass': '73'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Fe': 6.737979178156804e-05,
#                                 'H': 1.216130133911965e-06,
#                                 'O': 1.930407808452e-05}},
#  '0.127 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}},
#  '0.212 (m)': {'ion (g/m^2)': {'Fe': 5.680139443702152e-10,
#                                'H': 1.0252018535025781e-11,
#                                'O': 1.6273403709475906e-10}},
#  '0.296 (m)': {'ion (g/m^2)': {'Fe': 2.131010479553574e-11,
#                                'H': 3.8462363734644633e-13,
#                                'O': 6.1052715671178165e-12}},
#  '0.381 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}},
#  '0.55 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}},
#  '0.635 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}},
#  '0.72 (m)': {'ion (g/m^2)': {'Fe': 5.09756103921988e-11,
#                               'H': 9.200529454510317e-13,
#                               'O': 1.4604336662350173e-11}},
#  '0.804 (m)': {'ion (g/m^2)': {'Fe': 2.000696889077276e-10,
#                                'H': 3.6110348686123193e-12,
#                                'O': 5.731927622366007e-11}},
#  '0.889 (m)': {'ion (g/m^2)': {'Fe': 4.997909470032123e-10,
#                                'H': 9.020669480211619e-12,
#                                'O': 1.4318838351657613e-10}},
#  '0.974 (m)': {'ion (g/m^2)': {'Fe': 0.0, 'H': 0.0, 'O': 0.0}}}
#              Ferryhydrite (g/m^2)
# Distance (m)
# 4.23E-2                  8.790E-5
# 1.27E-1                   0.000E0
# 2.12E-1                 7.410E-10
# 2.96E-1                 2.780E-11
# 3.81E-1                   0.000E0
# 4.66E-1                   0.000E0
# 5.50E-1                   0.000E0
# 6.35E-1                   0.000E0
# 7.20E-1                 6.650E-11
# 8.04E-1                 2.610E-10
# 8.89E-1                 6.520E-10
# 9.74E-1                   0.000E0
# ==============================
#
# Tipping_Hurley database
#  ========================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Co'] elements are not accepted by the Tipping_Hurley database
#
# Estimated completion in 7 seconds: 2022-04-08 15:10:25.048501 local time.
#
#
# --> ERROR: The simulation with the Tipping_Hurley database failed to converge
# None
# ==============================
#
# wateq4f database
#  =================
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Co'] elements are not accepted by the wateq4f database
#
# Estimated completion in 7 seconds: 2022-04-08 15:10:25.661161 local time.
#
#
# --> ERROR: The simulation with the wateq4f database failed to converge
# None
