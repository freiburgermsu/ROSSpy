# %% [markdown]
# # Define and execute the simulation

# %%
# execute the ROSSpy simulation
# %run ../../../../rosspy/core.py
# from rosspy import ROSSPkg

# initial parameters
database_selection = 'pitzer'
simulation_perspective = 'all_distance'
simulation_time = 200

# Define the feed conditions
water_selection = 'Spacer_filled_channels'
water_characteristics = {
    'element': {
        'Ca': {
            'concentration (ppm)': 800
            }, 
        'S(6)': {
            'concentration (ppm)': 1975
        }
    },
    'pH': {
        'value': 6.4
    },
}

# create the input file
ross = ROSSPkg(database_selection)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection, water_characteristics)
ross.execute()

# execute and process the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177308071405103
#
# Estimated completion in 10.0 seconds, by 2022-01-20 21:15:03.557082 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# run_time (s): 0.6941805000000159
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': 172.17116000000001}
# {'1.27E-1 (m)': {'ion (g/m^2)': {'Ca': 1.7288909122376652,
#                                  'H': 0.0869613406896967,
#                                  'O': 3.4509228580836493,
#                                  'S': 1.3832248889889895}},
#  '2.12E-1 (m)': {'ion (g/m^2)': {'Ca': 1.6768941930726227,
#                                  'H': 0.0843459620223374,
#                                  'O': 3.3471357044570733,
#                                  'S': 1.3416241404479674}},
#  '2.96E-1 (m)': {'ion (g/m^2)': {'Ca': 1.627497309865832,
#                                  'H': 0.08186135228834607,
#                                  'O': 3.248537908511826,
#                                  'S': 1.3021034293339961}},
#  '3.81E-1 (m)': {'ion (g/m^2)': {'Ca': 1.5781004266590417,
#                                  'H': 0.07937674255435473,
#                                  'O': 3.149940112566579,
#                                  'S': 1.262582718220025}},
#  '4.66E-1 (m)': {'ion (g/m^2)': {'Ca': 1.5313033794105033,
#                                  'H': 0.07702290175373136,
#                                  'O': 3.0565316743026605,
#                                  'S': 1.225142044533105}},
#  '5.50E-1 (m)': {'ion (g/m^2)': {'Ca': 1.481906496203713,
#                                  'H': 0.07453829201974004,
#                                  'O': 2.9579338783574136,
#                                  'S': 1.185621333419134}},
#  '6.35E-1 (m)': {'ion (g/m^2)': {'Ca': 1.4351094489551746,
#                                  'H': 0.07218445121911665,
#                                  'O': 2.864525440093495,
#                                  'S': 1.1481806597322137}},
#  '7.20E-1 (m)': {'ion (g/m^2)': {'Ca': 1.3883124017066364,
#                                  'H': 0.06983061041849328,
#                                  'O': 2.7711170018295768,
#                                  'S': 1.1107399860452938}},
#  '8.04E-1 (m)': {'ion (g/m^2)': {'Ca': 1.341515354458098,
#                                  'H': 0.06747676961786993,
#                                  'O': 2.6777085635656586,
#                                  'S': 1.0732993123583738}},
#  '8.89E-1 (m)': {'ion (g/m^2)': {'Ca': 1.297318143167812,
#                                  'H': 0.06525369775061451,
#                                  'O': 2.589489482983069,
#                                  'S': 1.037938676098505}}}
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              6.65E0
# 2.12E-1              6.45E0
# 2.96E-1              6.26E0
# 3.81E-1              6.07E0
# 4.66E-1              5.89E0
# 5.50E-1              5.70E0
# 6.35E-1              5.52E0
# 7.20E-1              5.34E0
# 8.04E-1              5.16E0
# 8.89E-1              4.99E0
