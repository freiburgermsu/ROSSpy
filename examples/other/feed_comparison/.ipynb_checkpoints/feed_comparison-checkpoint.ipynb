# %% [markdown]
# # Evaluation of various feed water sources

# %%
# run the ROSS model
from glob import glob
import json
import os
# %run ../../../rosspy/core.py

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
for feed in glob(os.path.join(ross.parameters['root_path'], 'water_bodies', '*.json')):
    water_selection = os.path.basename(feed).split('.')[0] # json.load(open(feed))
    print(water_selection)
    
    ross = ROSSPkg(verbose = False)
    ross.define_general(database_selection, quantity_of_modules = quantity_of_modules)
    ross.transport(simulation_time, simulation_perspective, )
    ross.reaction()
    ross.solutions(water_selection)
    ross.equilibrium_phases()
    ross.selected_output()
    ross.export()

    # execute and process the input file
    raw_data = ross.execute()
    distance_data = ross.process_selected_output()
    display(distance_data)
# Out:
# bakken_formation
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:56:55.451970 local time.
#              Barite (g/m^2) Halite (g/m^2)
# Distance (m)
# 1.27E-1             6.11E-4         9.33E2
# 2.12E-1             5.87E-4         9.04E2
# 2.96E-1             5.64E-4         8.75E2
# 3.81E-1             5.42E-4         8.46E2
# 4.66E-1             5.20E-4         8.18E2
# 5.50E-1             4.99E-4         7.90E2
# 6.35E-1             4.78E-4         7.63E2
# 7.20E-1             4.58E-4         7.36E2
# 8.04E-1             4.39E-4         7.09E2
# 8.89E-1             4.20E-4         6.83E2
# marcellus_appalachian_basin
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:01.874475 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Brucite (g/m^2) Portlandite (g/m^2)
# Distance (m)
# 1.27E-1             2.75E-3          0.00E0              4.20E0
# 2.12E-1             2.65E-3          0.00E0              4.06E0
# 2.96E-1             2.54E-3          0.00E0              3.93E0
# 3.81E-1             2.44E-3          0.00E0              3.79E0
# 4.66E-1             2.34E-3          0.00E0              3.66E0
# 5.50E-1             2.24E-3          0.00E0              3.53E0
# 6.35E-1             2.15E-3          0.00E0              3.40E0
# 7.20E-1             2.06E-3          0.00E0              3.27E0
# 8.04E-1             1.97E-3          0.00E0              3.15E0
# 8.89E-1             1.88E-3          0.00E0              3.03E0
# mediterranean_sea
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:09.015641 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Goergeyite (g/m^2)
# Distance (m)
# 1.27E-1                  0.00E0
# 2.12E-1                  0.00E0
# 2.96E-1                  0.00E0
# 3.81E-1                  0.00E0
# 4.66E-1                  4.57E0
# 5.50E-1                  5.05E0
# 6.35E-1                  4.69E0
# 7.20E-1                  4.29E0
# 8.04E-1                  3.89E0
# 8.89E-1                  3.51E0
# michigan_basin
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:14.763545 local time.
#              Barite (g/m^2) Halite (g/m^2)
# Distance (m)
# 1.27E-1             3.96E-4         8.97E2
# 2.12E-1             3.56E-4         8.67E2
# 2.96E-1             3.31E-4         8.38E2
# 3.81E-1             3.14E-4         8.09E2
# 4.66E-1             3.02E-4         7.81E2
# 5.50E-1             2.98E-4         7.53E2
# 6.35E-1             2.98E-4         7.26E2
# 7.20E-1             3.05E-4         6.99E2
# 8.04E-1             3.15E-4         6.73E2
# 8.89E-1             3.31E-4         6.47E2
# north_german_basin
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:22.118849 local time.
#              Barite (g/m^2) Halite (g/m^2)
# Distance (m)
# 1.27E-1             9.21E-4         9.50E2
# 2.12E-1             8.85E-4         9.20E2
# 2.96E-1             8.50E-4         8.91E2
# 3.81E-1             8.18E-4         8.62E2
# 4.66E-1             7.86E-4         8.33E2
# 5.50E-1             7.56E-4         8.05E2
# 6.35E-1             7.26E-4         7.77E2
# 7.20E-1             6.98E-4         7.50E2
# 8.04E-1             6.70E-4         7.23E2
# 8.89E-1             6.43E-4         6.97E2
# palo_duro_basin
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:28.512055 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Brucite (g/m^2)
# Distance (m)
# 1.27E-1             6.39E-3          0.00E0
# 2.12E-1             6.03E-3          0.00E0
# 2.96E-1             5.74E-3          0.00E0
# 3.81E-1             5.46E-3          0.00E0
# 4.66E-1             5.21E-3          0.00E0
# 5.50E-1             4.97E-3          0.00E0
# 6.35E-1             4.74E-3          0.00E0
# 7.20E-1             4.53E-3          0.00E0
# 8.04E-1             4.32E-3          0.00E0
# 8.89E-1             4.13E-3          0.00E0
# red_sea
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:35.508041 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             4.39E-1
# 5.50E-1              8.21E0
# 6.35E-1              7.98E0
# 7.20E-1              7.71E0
# 8.04E-1              7.45E0
# 8.89E-1              7.19E0
# western_pennsylvania_basin
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 14 significant figures requested from number with only 13 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Estimated completion in 3.80E1 seconds by 2021-10-28 21:57:41.320927 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Brucite (g/m^2) Portlandite (g/m^2)
# Distance (m)
# 1.27E-1             1.64E-3          0.00E0              3.15E0
# 2.12E-1             1.44E-3          0.00E0              3.03E0
# 2.96E-1             1.26E-3          0.00E0              2.92E0
# 3.81E-1             1.08E-3          0.00E0              2.81E0
# 4.66E-1             9.19E-4          0.00E0              2.71E0
# 5.50E-1             7.66E-4          0.00E0              2.60E0
# 6.35E-1             6.24E-4          0.00E0              2.50E0
# 7.20E-1             4.93E-4          0.00E0              2.40E0
# 8.04E-1             3.75E-4          0.00E0              2.31E0
# 8.89E-1             2.70E-4          0.00E0              2.21E0
