# %% [markdown]
# # Single versus Dual domain

# %% [markdown]
# ## Single domain

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg()
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# general parameters
simulation_name = 'single_domain-brine'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 1.70E1 seconds by 2022-01-02 20:08:40.695120 local time.
#          Mn(mol/kgw) Fe(mol/kgw) B(mol/kgw) Cl(mol/kgw) Na(mol/kgw)  \
# Time (s)
# 4.34E1     1.237E-14   2.497E-13  2.761E-10    1.551E-6    1.586E-6
# 4.74E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.406E-1
# 5.13E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 5.52E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 5.92E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 6.31E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 6.71E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 7.10E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 7.50E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
# 7.89E1      6.557E-9    1.324E-7   1.464E-4    8.220E-1    8.407E-1
#
#          S(6)(mol/kgw) Ca(mol/kgw) K(mol/kgw) Mg(mol/kgw) Sr(mol/kgw)  \
# Time (s)
# 4.34E1        2.193E-7    4.255E-8   1.709E-8    1.504E-7   2.103E-10
# 4.74E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.13E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.52E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 5.92E1        1.153E-1    2.158E-2   9.063E-3    7.972E-2    1.115E-4
# 6.31E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 6.71E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.10E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.50E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
# 7.89E1        1.153E-1    2.157E-2   9.063E-3    7.972E-2    1.115E-4
#
#          Ba(mol/kgw) Li(mol/kgw)  Zn(mol/kgw)  Ni(mol/kgw)  Cu(mol/kgw)  \
# Time (s)
# 4.34E1     1.779E-13   7.294E-11          NaN          NaN          NaN
# 4.74E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 5.13E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 5.52E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 5.92E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 6.31E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 6.71E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 7.10E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 7.50E1      9.429E-8    3.867E-5          NaN          NaN          NaN
# 7.89E1      9.429E-8    3.867E-5          NaN          NaN          NaN
#
#           Cd(mol/kgw)  Co(mol/kgw)  Pb(mol/kgw)
# Time (s)
# 4.34E1            NaN          NaN          NaN
# 4.74E1            NaN          NaN          NaN
# 5.13E1            NaN          NaN          NaN
# 5.52E1            NaN          NaN          NaN
# 5.92E1            NaN          NaN          NaN
# 6.31E1            NaN          NaN          NaN
# 6.71E1            NaN          NaN          NaN
# 7.10E1            NaN          NaN          NaN
# 7.50E1            NaN          NaN          NaN
# 7.89E1            NaN          NaN          NaN

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
simulation_name = 'single_domain-scaling'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection,)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-02 20:09:04.681003 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             1.96E-2
# 5.50E-1              8.13E0
# 6.35E-1              8.00E0
# 7.20E-1              7.76E0
# 8.04E-1              7.51E0
# 8.89E-1              7.27E0

# %% [markdown]
# ## Dual domain

# %% [markdown]
# ## Immobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg()
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# general parameters
simulation_name = 'dual_domain-immobile-brine'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'immobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 1.70E1 seconds by 2022-01-02 20:08:50.087435 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# --> ERROR: The {'Fe(mol/kgw)', 'Cl(mol/kgw)', 'Li(mol/kgw)', 'B(mol/kgw)', 'Na(mol/kgw)', 'S(6)(mol/kgw)', 'Ca(mol/kgw)', 'Sr(mol/kgw)', 'Ba(mol/kgw)', 'Mn(mol/kgw)', 'K(mol/kgw)', 'Mg(mol/kgw)'} elements remain below the 1E-16 Molal threshold.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-25b13d00bd10> in <module>
#      25 # execute the input file
#      26 raw_data = ross.execute()
# ---> 27 brine_data = ross.process_selected_output()
#      28 display(brine_data)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in process_selected_output(self, selected_output_path, scale_ions, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots)
#     930         # conducting the appropriate visualization function
#     931         if self.parameters['simulation'] == 'brine':
# --> 932             data = self.brine_plot(pyplot, title_font, label_font, export_format, x_label_number, export_name)
#     933         elif self.parameters['simulation'] == 'scaling':
#     934             data = self.scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in brine_plot(self, pyplot, title_font, label_font, export_format, x_label_number, export_name)
#    1115             for x in range(x_label_number):
#    1116                 index = int(index_space * x)
# -> 1117                 time = time_serie[index]
#    1118                 x_location.append(time)
#    1119             x_location.append(time_serie[-1])
#
# IndexError: list index out of range

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
simulation_name = 'dual_domain-immobile-scaling'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'immobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-02 20:09:22.406255 local time.
# No scaling occurred.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c6479c75a36e> in <module>
#      25 # execute and process the input file
#      26 raw_data = ross.execute()
# ---> 27 scaling_data = ross.process_selected_output()
#      28 display(scaling_data)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in process_selected_output(self, selected_output_path, scale_ions, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots)
#     934             data = self.scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#     935             if scale_ions:
# --> 936                 self.ion_proportions(data)
#     937         else:
#     938             print('--> ERROR: The < simulation_perspective > parameter is unpredicted.')
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in ion_proportions(self, data)
#     945         stoich = None
#     946         total = 0
# --> 947         for column in data:
#     948             mineral = re.search('([A-Za-z]+)', column).group()
#     949             formula = self.minerals[mineral]['formula']
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ## Mobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg()
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# general parameters
simulation_name = 'dual_domain-mobile-brine'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
domain = 'dual'
domain_phase = 'mobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute the input file
raw_data = ross.execute()
brine_data = ross.process_selected_output()
display(brine_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 1.70E1 seconds by 2022-01-02 20:09:14.615720 local time.
#
#
# --> ERROR: The {'Fe(mol/kgw)', 'Cl(mol/kgw)', 'Li(mol/kgw)', 'B(mol/kgw)', 'Na(mol/kgw)', 'S(6)(mol/kgw)', 'Ca(mol/kgw)', 'Sr(mol/kgw)', 'Ba(mol/kgw)', 'Mn(mol/kgw)', 'K(mol/kgw)', 'Mg(mol/kgw)'} elements remain below the 1E-16 Molal threshold.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-ccd7f1639e89> in <module>
#      25 # execute the input file
#      26 raw_data = ross.execute()
# ---> 27 brine_data = ross.process_selected_output()
#      28 display(brine_data)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in process_selected_output(self, selected_output_path, scale_ions, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots)
#     930         # conducting the appropriate visualization function
#     931         if self.parameters['simulation'] == 'brine':
# --> 932             data = self.brine_plot(pyplot, title_font, label_font, export_format, x_label_number, export_name)
#     933         elif self.parameters['simulation'] == 'scaling':
#     934             data = self.scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in brine_plot(self, pyplot, title_font, label_font, export_format, x_label_number, export_name)
#    1115             for x in range(x_label_number):
#    1116                 index = int(index_space * x)
# -> 1117                 time = time_serie[index]
#    1118                 x_location.append(time)
#    1119             x_location.append(time_serie[-1])
#
# IndexError: list index out of range

# %% [markdown]
# ### Scaling

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
simulation_name = 'dual_domain-mobile-scaling'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
domain = 'dual'
domain_phase = 'mobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, simulation, domain, domain_phase)
ross.transport(simulation_time, simulation_perspective)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(simulation_name)

# execute and process the input file
raw_data = ross.execute()
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-02 20:09:43.086939 local time.
# No scaling occurred.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-cef4c49254ab> in <module>
#      25 # execute and process the input file
#      26 raw_data = ross.execute()
# ---> 27 scaling_data = ross.process_selected_output()
#      28 display(scaling_data)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in process_selected_output(self, selected_output_path, scale_ions, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots)
#     934             data = self.scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#     935             if scale_ions:
# --> 936                 self.ion_proportions(data)
#     937         else:
#     938             print('--> ERROR: The < simulation_perspective > parameter is unpredicted.')
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in ion_proportions(self, data)
#     945         stoich = None
#     946         total = 0
# --> 947         for column in data:
#     948             mineral = re.search('([A-Za-z]+)', column).group()
#     949             formula = self.minerals[mineral]['formula']
#
# TypeError: 'NoneType' object is not iterable
