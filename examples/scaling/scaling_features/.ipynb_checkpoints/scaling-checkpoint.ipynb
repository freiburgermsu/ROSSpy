# %% [markdown]
# # Red Sea scaling through BW30-400

# %% [markdown]
# ## Evaluate scaling along the module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross.define_general(database_selection, quantity_of_modules = quantity_of_modules)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
distance_data = ross.process_selected_output()
display(distance_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-04 20:42:29.639919 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             1.96E-2
# 5.50E-1              8.13E0
# 6.35E-1              8.00E0
# 7.20E-1              7.76E0
# 8.04E-1              7.51E0
# 8.89E-1              7.27E0

# %% [markdown]
# ## Evaluate the accumulation of module end scaling over time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)
# import rosspy
# ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
quantity_of_modules = 1
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_perspective = 'all_time'
simulation_time = 200

# create the input file
ross.define_general(database_selection, quantity_of_modules = quantity_of_modules)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
time_data = ross.process_selected_output()
display(time_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-04 20:42:36.129964 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#          Gypsum (g/m^2)
# Time (s)
# 1.026E2         2.594E0
# 1.066E2         2.770E0
# 1.105E2         2.947E0
# 1.144E2         3.124E0
# 1.184E2         3.301E0
# 1.223E2         3.478E0
# 1.263E2         3.656E0
# 1.302E2         3.833E0
# 1.342E2         4.011E0
# 1.381E2         4.188E0
# 1.421E2         4.366E0
# 1.460E2         4.544E0
# 1.500E2         4.721E0
# 1.539E2         4.899E0
# 1.579E2         5.077E0
# 1.618E2         5.255E0
# 1.657E2         5.433E0
# 1.697E2         5.610E0
# 1.736E2         5.788E0
# 1.776E2         5.966E0
# 1.815E2         6.144E0
# 1.855E2         6.322E0
# 1.894E2         6.500E0
# 1.934E2         6.677E0
# 1.973E2         6.855E0
# 2.013E2         7.033E0
# 4.736E1        1.187E-1
# 5.130E1        2.969E-1
# 5.525E1        4.750E-1
# 5.919E1        6.528E-1
# 6.314E1        8.305E-1
# 6.709E1         1.008E0
# 7.103E1         1.185E0
# 7.498E1         1.361E0
# 7.893E1         1.538E0
# 8.287E1         1.714E0
# 8.682E1         1.890E0
# 9.077E1         2.066E0
# 9.471E1         2.241E0
# 9.866E1         2.418E0

# %% [markdown]
# ## Evaluate scaling over a custom, high permeate, module at the final time

# %%
# run the ROSS model
# %run ../../rosspy/core.py
# ross = ROSSPkg(verbose = False)
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_distance'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_hour': 12.5}

# create the input file
ross.define_general(database_selection)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
high_permeate_distance_data = ross.process_selected_output()
display(high_permeate_distance_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-04 20:42:42.583498 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Barite (g/m^2) Celestite (g/m^2) Goergeyite (g/m^2)  \
# Distance (m)
# 1.27E-1              0.00E0            0.00E0             0.00E0
# 2.12E-1              0.00E0            0.00E0             0.00E0
# 2.96E-1              0.00E0            0.00E0             2.32E0
# 3.81E-1              0.00E0            0.00E0             7.45E1
# 4.66E-1              0.00E0            0.00E0             7.41E1
# 5.50E-1             3.31E-4           4.26E-1             7.34E1
# 6.35E-1             6.66E-4           6.59E-1             7.27E1
# 7.20E-1             6.61E-4           6.63E-1             7.21E1
# 8.04E-1             6.45E-4           6.65E-1             7.12E1
# 8.89E-1             6.04E-4           6.55E-1             6.90E1
#
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              7.30E1
# 2.12E-1              7.20E1
# 2.96E-1              6.87E1
# 3.81E-1              0.00E0
# 4.66E-1              0.00E0
# 5.50E-1              0.00E0
# 6.35E-1              0.00E0
# 7.20E-1              0.00E0
# 8.04E-1              0.00E0
# 8.89E-1              0.00E0

# %% [markdown]
# ## Evaluate the accumulation of scaling at the end of the high permeate module over time

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)
# import rosspy
# ross = rosspy.ROSSPkg(verbose = False)

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation_time = 200
simulation_perspective = 'all_time'

# custom module parameterization
module_characteristics = {'permeate_flow_m3_per_hour': 12.5}

# create the input file
ross.define_general(database_selection)
ross.transport(simulation_time, simulation_perspective, module_characteristics)
ross.reaction()
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export()

# execute and process the input file
raw_data = ross.execute()
high_permeate_time_data = ross.process_selected_output()
display(high_permeate_time_data)
# Out:
# --> ERROR: The Zn element is not accepted by the pitzer database
#
# --> ERROR: The Ni element is not accepted by the pitzer database
#
# --> ERROR: The Cu element is not accepted by the pitzer database
#
# --> ERROR: The Cd element is not accepted by the pitzer database
#
# --> ERROR: The Co element is not accepted by the pitzer database
#
# --> ERROR: The Pb element is not accepted by the pitzer database
#
#
#
#
# Estimated completion in 3.80E1 seconds by 2022-01-04 20:42:50.823420 local time.
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#          Barite (g/m^2) Celestite (g/m^2) Goergeyite (g/m^2)
# Time (s)
# 1.026E2        1.922E-4          2.249E-1            2.362E1
# 1.066E2        2.052E-4          2.403E-1            2.522E1
# 1.105E2        2.181E-4          2.557E-1            2.683E1
# 1.144E2        2.311E-4          2.710E-1            2.843E1
# 1.184E2        2.441E-4          2.864E-1            3.003E1
# 1.223E2        2.571E-4          3.018E-1            3.163E1
# 1.263E2        2.700E-4          3.172E-1            3.323E1
# 1.302E2        2.830E-4          3.326E-1            3.483E1
# 1.342E2        2.960E-4          3.480E-1            3.644E1
# 1.381E2        3.090E-4          3.634E-1            3.804E1
# 1.421E2        3.219E-4          3.788E-1            3.964E1
# 1.460E2        3.349E-4          3.941E-1            4.124E1
# 1.500E2        3.479E-4          4.095E-1            4.284E1
# 1.539E2        3.609E-4          4.249E-1            4.444E1
# 1.579E2        3.738E-4          4.403E-1            4.604E1
# 1.618E2        3.868E-4          4.557E-1            4.764E1
# 1.657E2        3.998E-4          4.711E-1            4.925E1
# 1.697E2        4.128E-4          4.865E-1            5.085E1
# 1.736E2        4.258E-4          5.019E-1            5.245E1
# 1.776E2        4.387E-4          5.172E-1            5.405E1
# 1.815E2        4.517E-4          5.326E-1            5.565E1
# 1.855E2        4.647E-4          5.480E-1            5.725E1
# 1.894E2        4.777E-4          5.634E-1            5.885E1
# 1.934E2        4.906E-4          5.788E-1            6.046E1
# 1.973E2        5.036E-4          5.942E-1            6.206E1
# 2.013E2        5.166E-4          6.096E-1            6.366E1
# 4.736E1        9.093E-6          1.036E-2            1.094E0
# 5.130E1        2.225E-5          2.565E-2            2.709E0
# 5.525E1        3.541E-5          4.094E-2            4.323E0
# 5.919E1        4.856E-5          5.623E-2            5.937E0
# 6.314E1        6.170E-5          7.153E-2            7.549E0
# 6.709E1        7.483E-5          8.683E-2            9.161E0
# 7.103E1        8.794E-5          1.021E-1            1.077E1
# 7.498E1        1.010E-4          1.175E-1            1.238E1
# 7.893E1        1.141E-4          1.328E-1            1.399E1
# 8.287E1        1.271E-4          1.481E-1            1.560E1
# 8.682E1        1.402E-4          1.635E-1            1.720E1
# 9.077E1        1.532E-4          1.788E-1            1.881E1
# 9.471E1        1.662E-4          1.942E-1            2.041E1
# 9.866E1        1.792E-4          2.095E-1            2.202E1
