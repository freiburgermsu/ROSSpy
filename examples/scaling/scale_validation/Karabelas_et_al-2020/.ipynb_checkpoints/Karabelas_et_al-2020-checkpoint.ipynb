# %% [markdown]
# # Define the simulation parameters

# %%
# execute the ROSSpy simulation
# from rosspy import ROSSPkg 

# Define the feed conditions
water_selection = 'brackish-water'
water_characteristics = {
    'element': {
        'Li': {
            'concentration (ppm)': 0.04
        },
        'Na': {
            'concentration (ppm)': 701
        },
        'Mg': {
            'concentration (ppm)': 96
        },
        'Ca': {
            'concentration (ppm)': 250
        }, 
        'K': {
            'concentration (ppm)': 34
        },
        'Mn': {
            'concentration (ppm)': 0.09
        }, 
        'Fe': {
            'concentration (ppm)': 9.8
        }, 
        'Co': {
            'concentration (ppm)': 0.13
        }, 
        'Cu': {
            'concentration (ppm)': 0.03
        }, 
        'S(6)': {
            'concentration (ppm)': 433.8,
            'form': 'SO4'
        }, 
        'Cl': {
            'concentration (ppm)': 1400
        }, 
        'F': {
            'concentration (ppm)': 0.7
        },
        'N(5)': {
            'concentration (ppm)': 9.2,
            'form': 'NO3'
        },
        'Ba': {
            'concentration (ppm)': 0.05
        },
        'B': {
            'concentration (ppm)': 0.55
        },
        'Sr': {
            'concentration (ppm)': 6.2
        },
        'Si': {
            'concentration (ppm)': 26,
            'form': 'SiO2'
        },
        'C(4)': {
            'concentration (ppm)': 0.2,
            'form': 'CO3'
        },
    },
    'temperature': {
        'value': 31
    },
    'Alkalinity': {
        'value': 192.7,
        'form': 'HCO3'
    },
    'pH': {
        'value': 6.8
    },
}

# define the module characteristics
permeate_recovery = 0.68
module_characteristics = {
    'max_feed_flow_m3_per_hour': {
        'value':10.5
    },
    'permeate_flow_m3_per_hour':  {
        'value':permeate_recovery*10.58
    },
    'active_m2': {
        'value':37
    }
}

# general parameters
simulation_perspective = 'all_distance'
simulation_time = 200

# %% [markdown]
# # Execution with all of the databases

# %%
from glob import glob
import os, re

# loop through the databases
# %run ../../../../rosspy/ro.py
for db in ross.databases:
    # create the input file    
    print('\n', db, 'database\n', '='*2*len(f'{db} database'))
    ross = ROSSPkg(db, printing = False, export_content = True)
    ross.reactive_transport(simulation_time, simulation_perspective, module_characteristics = module_characteristics)
    ross.feed_geochemistry(water_selection, water_characteristics)
    ross.execute(f'{db} scaling', figure_title = f'Scaling from {water_selection}, via the {db} database')
    display(ross.processed_data)
# Out:
#  Amm database
#  ========================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the Amm database
#
# Estimated completion in 7 seconds: 2022-04-08 11:16:51.814159 local time.
# run_time (s): 2.7798245000012685
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0          2.630E0       3.150E-3
# 1.27E-1              0.000E0         8.310E-2       9.760E-4
# 2.12E-1              0.000E0         7.890E-2       9.270E-4
# 2.96E-1              0.000E0         7.480E-2       8.790E-4
# 3.81E-1              0.000E0         7.060E-2       8.320E-4
# 4.66E-1              0.000E0         6.660E-2       7.870E-4
# 5.50E-1             5.230E-1         3.330E-2       7.510E-4
# 6.35E-1              1.090E0         3.370E-3       7.150E-4
# 7.20E-1              1.150E0         3.480E-3       6.720E-4
# 8.04E-1              1.220E0         3.560E-3       6.300E-4
# 8.89E-1              1.310E0         3.590E-3       5.890E-4
# 9.74E-1              1.410E0         3.510E-3       5.500E-4
#  ColdChem database
#  ==================================
#
# --> The ['Li', 'Mn', 'Fe', 'Co', 'Cu', 'F', 'N(5)', 'Ba', 'B', 'Sr', 'Si', 'C(4)'] elements are not accepted by the ColdChem database
#
# Estimated completion in 7 seconds: 2022-04-08 11:16:54.801581 local time.
# run_time (s): 1.7669926000089617
# No scaling occurred.
# None
#  core10 database
#  ==============================
#
# --> The ['S(6)', 'F', 'N(5)', 'Ba', 'Sr', 'C(4)'] elements are not accepted by the core10 database
#
# Estimated completion in 7 seconds: 2022-04-08 11:16:56.599552 local time.
# run_time (s): 5.487365499997395
#              Dolomite (g/m^2) Siderite (g/m^2)
# Distance (m)
# 4.23E-2               6.280E0         8.160E-2
# 1.27E-1              5.440E-1         1.280E-2
# 2.12E-1              5.510E-1         1.270E-2
# 2.96E-1              5.590E-1         1.260E-2
# 3.81E-1              5.680E-1         1.240E-2
# 4.66E-1              5.770E-1         1.210E-2
# 5.50E-1              5.870E-1         1.180E-2
# 6.35E-1              5.990E-1         1.140E-2
# 7.20E-1              6.110E-1         1.080E-2
# 8.04E-1              6.260E-1         1.010E-2
# 8.89E-1              6.430E-1         9.090E-3
# 9.74E-1              6.650E-1         7.690E-3
#  frezchem database
#  ==================================
#
# --> The ['Li', 'Mn', 'Fe', 'Co', 'Cu', 'F', 'N(5)', 'Ba', 'B', 'Sr', 'Si'] elements are not accepted by the frezchem database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:02.272938 local time.
# run_time (s): 2.470504199998686
#              Hydromagnesite (g/m^2)
# Distance (m)
# 4.23E-2                    6.230E-2
# 1.27E-1                    1.820E-3
# 2.12E-1                    1.640E-3
# 2.96E-1                    1.480E-3
# 3.81E-1                    1.330E-3
# 4.66E-1                    1.180E-3
# 5.50E-1                    1.050E-3
# 6.35E-1                    9.270E-4
# 7.20E-1                    8.120E-4
# 8.04E-1                    7.060E-4
# 8.89E-1                    6.080E-4
# 9.74E-1                    5.170E-4
#  iso database
#  ========================
#
# --> The ['Li', 'Mn', 'Co', 'Cu', 'N(5)', 'Ba', 'B', 'Sr'] elements are not accepted by the iso database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:04.894165 local time.
# run_time (s): 4.916356400004588
#              Calcite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0
# 1.27E-1              0.000E0
# 2.12E-1              0.000E0
# 2.96E-1              0.000E0
# 3.81E-1              0.000E0
# 4.66E-1              0.000E0
# 5.50E-1              0.000E0
# 6.35E-1              0.000E0
# 7.20E-1              0.000E0
# 8.04E-1              0.000E0
# 8.89E-1              0.000E0
# 9.74E-1             2.070E-3
#  llnl database
#  ==========================
#
# --> The ['S(6)', 'N(5)', 'C(4)'] elements are not accepted by the llnl database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:09.919279 local time.
# run_time (s): 10.629919099999825
#              Dolomite (g/m^2) Witherite (g/m^2)
# Distance (m)
# 4.23E-2               5.650E0          3.200E-3
# 1.27E-1              5.170E-1          1.860E-5
# 2.12E-1              5.240E-1          1.730E-5
# 2.96E-1              5.320E-1          1.560E-5
# 3.81E-1              5.410E-1          1.370E-5
# 4.66E-1              5.500E-1          1.130E-5
# 5.50E-1              5.600E-1          8.350E-6
# 6.35E-1              5.720E-1          4.720E-6
# 7.20E-1              5.840E-1          1.440E-7
# 8.04E-1              5.990E-1           0.000E0
# 8.89E-1              6.160E-1           0.000E0
# 9.74E-1              6.370E-1           0.000E0
#  minteq database
#  ==============================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the minteq database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:20.693549 local time.
# run_time (s): 5.404994900003658
#              Barite (g/m^2) Calcite (g/m^2) Ferrihydrite (g/m^2)  \
# Distance (m)
# 4.23E-2            8.710E-3         0.000E0             1.020E-1
# 1.27E-1            5.700E-4         0.000E0             2.010E-5
# 2.12E-1            5.380E-4         0.000E0             2.030E-5
# 2.96E-1            5.080E-4         0.000E0             2.040E-5
# 3.81E-1            4.780E-4         0.000E0             2.060E-5
# 4.66E-1            4.490E-4         0.000E0             2.070E-5
# 5.50E-1            4.220E-4         0.000E0             2.080E-5
# 6.35E-1            3.970E-4        2.060E-1             1.510E-5
# 7.20E-1            3.760E-4        9.790E-1              0.000E0
# 8.04E-1            3.500E-4         1.050E0              0.000E0
# 8.89E-1            3.250E-4         1.120E0              0.000E0
# 9.74E-1            3.010E-4         1.210E0              0.000E0
#
#              Siderite (g/m^2)
# Distance (m)
# 4.23E-2               1.520E0
# 1.27E-1              1.730E-1
# 2.12E-1              1.670E-1
# 2.96E-1              1.600E-1
# 3.81E-1              1.540E-1
# 4.66E-1              1.470E-1
# 5.50E-1              1.400E-1
# 6.35E-1              1.050E-1
# 7.20E-1              6.810E-3
# 8.04E-1              6.740E-3
# 8.89E-1              6.470E-3
# 9.74E-1              5.860E-3
#  minteq.v4 database
#  ====================================
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:26.422630 local time.
# run_time (s): 6.925214799994137
#              Ferrihydrite (g/m^2) Brucite (g/m^2) Atacamite (g/m^2)  \
# Distance (m)
# 4.23E-2                   2.470E0         1.000E1          5.760E-3
# 1.27E-1                  4.380E-6        4.190E-2          3.770E-4
# 2.12E-1                  4.170E-6        4.070E-2          3.490E-4
# 2.96E-1                  3.960E-6        3.950E-2          3.220E-4
# 3.81E-1                  3.760E-6        3.840E-2          2.960E-4
# 4.66E-1                  3.560E-6        3.730E-2          2.710E-4
# 5.50E-1                  3.360E-6        3.640E-2          2.470E-4
# 6.35E-1                  3.170E-6        3.550E-2          2.240E-4
# 7.20E-1                  2.990E-6        3.480E-2          2.020E-4
# 8.04E-1                  2.800E-6        3.430E-2          1.810E-4
# 8.89E-1                  2.620E-6        3.400E-2          1.600E-4
# 9.74E-1                  2.440E-6        3.410E-2          1.410E-4
#
#              Barite (g/m^2)
# Distance (m)
# 4.23E-2            9.210E-3
# 1.27E-1            5.540E-4
# 2.12E-1            5.240E-4
# 2.96E-1            4.940E-4
# 3.81E-1            4.650E-4
# 4.66E-1            4.380E-4
# 5.50E-1            4.110E-4
# 6.35E-1            3.850E-4
# 7.20E-1            3.600E-4
# 8.04E-1            3.360E-4
# 8.89E-1            3.130E-4
# 9.74E-1            2.910E-4
#  phreeqc database
#  ================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the phreeqc database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:33.767768 local time.
# run_time (s): 2.7781657000014093
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0          2.730E0       3.100E-3
# 1.27E-1              0.000E0         8.610E-2       9.620E-4
# 2.12E-1              0.000E0         8.180E-2       9.130E-4
# 2.96E-1              0.000E0         7.740E-2       8.660E-4
# 3.81E-1              0.000E0         7.320E-2       8.200E-4
# 4.66E-1              0.000E0         6.890E-2       7.750E-4
# 5.50E-1             5.230E-1         3.450E-2       7.400E-4
# 6.35E-1              1.090E0         3.490E-3       7.040E-4
# 7.20E-1              1.150E0         3.600E-3       6.620E-4
# 8.04E-1              1.220E0         3.680E-3       6.210E-4
# 8.89E-1              1.300E0         3.710E-3       5.810E-4
# 9.74E-1              1.400E0         3.630E-3       5.420E-4
#  pitzer database
#  ==============================
#
# --> The ['Co', 'Cu', 'F', 'N(5)'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-08 11:17:36.741320 local time.
# run_time (s): 6.023096400007489
#              Barite (g/m^2) Brucite (g/m^2) Calcite (g/m^2)
# Distance (m)
# 4.23E-2            6.690E-3         1.320E1         0.000E0
# 1.27E-1            7.180E-4        4.990E-2         0.000E0
# 2.12E-1            6.770E-4        4.800E-2         0.000E0
# 2.96E-1            6.380E-4        4.610E-2         0.000E0
# 3.81E-1            6.010E-4        4.430E-2         0.000E0
# 4.66E-1            5.640E-4        4.250E-2         0.000E0
# 5.50E-1            5.290E-4        4.080E-2         0.000E0
# 6.35E-1            4.960E-4        3.910E-2         0.000E0
# 7.20E-1            4.630E-4        3.750E-2         0.000E0
# 8.04E-1            4.320E-4        3.570E-2        2.810E-3
# 8.89E-1            4.020E-4        3.390E-2        6.930E-3
# 9.74E-1            3.740E-4        3.250E-2        6.440E-3
#  sit database
#  ========================
#
# --> The ['S(6)', 'N(5)', 'C(4)'] elements are not accepted by the sit database
#
# Estimated completion in 54 seconds: 2022-04-08 11:18:30.095497 local time.
# run_time (s): 36.75170409999555
#              Calcite (g/m^2) Ferryhydrite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0              2.450E0
# 1.27E-1              0.000E0              0.000E0
# 2.12E-1              0.000E0              0.000E0
# 2.96E-1              0.000E0              0.000E0
# 3.81E-1              0.000E0              0.000E0
# 4.66E-1              0.000E0              0.000E0
# 5.50E-1             6.870E-1              0.000E0
# 6.35E-1              1.010E0              0.000E0
# 7.20E-1              1.070E0              0.000E0
# 8.04E-1              1.130E0              0.000E0
# 8.89E-1              1.210E0              0.000E0
# 9.74E-1              1.300E0              0.000E0
#  Tipping_Hurley database
#  ==============================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the Tipping_Hurley database
#
# Estimated completion in 7 seconds: 2022-04-08 11:18:19.868374 local time.
# run_time (s): 5.044972000003327
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0          2.730E0       6.520E-3
# 1.27E-1              0.000E0         8.600E-2       7.150E-4
# 2.12E-1              0.000E0         8.170E-2       6.780E-4
# 2.96E-1              0.000E0         7.730E-2       6.420E-4
# 3.81E-1              0.000E0         7.310E-2       6.080E-4
# 4.66E-1              0.000E0         6.880E-2       5.740E-4
# 5.50E-1             4.370E-1         3.960E-2       5.470E-4
# 6.35E-1              1.080E0         3.580E-3       5.210E-4
# 7.20E-1              1.150E0         3.680E-3       4.890E-4
# 8.04E-1              1.220E0         3.770E-3       4.580E-4
# 8.89E-1              1.300E0         3.790E-3       4.270E-4
# 9.74E-1              1.400E0         3.700E-3       3.980E-4
#  wateq4f database
#  ================================
#
# --> The ['Co', 'N(5)', 'C(4)'] elements are not accepted by the wateq4f database
#
# Estimated completion in 7 seconds: 2022-04-08 11:18:25.120911 local time.
# run_time (s): 5.030049899985897
#              Calcite (g/m^2) Siderite (g/m^2) Barite (g/m^2)
# Distance (m)
# 4.23E-2              0.000E0          2.730E0       6.520E-3
# 1.27E-1              0.000E0         8.600E-2       7.150E-4
# 2.12E-1              0.000E0         8.170E-2       6.780E-4
# 2.96E-1              0.000E0         7.730E-2       6.420E-4
# 3.81E-1              0.000E0         7.310E-2       6.080E-4
# 4.66E-1              0.000E0         6.880E-2       5.740E-4
# 5.50E-1             4.370E-1         3.960E-2       5.470E-4
# 6.35E-1              1.080E0         3.580E-3       5.210E-4
# 7.20E-1              1.150E0         3.680E-3       4.890E-4
# 8.04E-1              1.220E0         3.770E-3       4.580E-4
# 8.89E-1              1.300E0         3.790E-3       4.270E-4
# 9.74E-1              1.400E0         3.700E-3       3.980E-4
