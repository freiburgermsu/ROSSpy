# %% [markdown]
# # Linear permeate vs. linear CF

# %% [markdown]
# ## Linear CF - Brine

# %%
# %run ../../../rosspy/core.py
# import rosspy


# general parameters
database_selection = 'pitzer'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75
final_cf = 1.117096

# execute the simulation
ross = ROSSPkg(database_selection, simulation, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective, final_cf)
ross.feed_geochemistry(water_selection)
ross.execute()
display(ross.processed_data)
# Out:
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 6.64 seconds: 2022-01-21 15:06:14.743112 local time.
# run_time (s): 2.1547448999999688
#            Mn(mol/kgw)   Fe(mol/kgw)    B(mol/kgw)  Cl(mol/kgw)  Na(mol/kgw)  \
# Time (s)
# 4.34E1    1.235906e-14  2.495546e-13  2.758737e-10     0.000002     0.000002
# 4.74E1    6.554227e-09  1.323433e-07  1.463007e-04     0.821676     0.840305
# 5.13E1    6.554239e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 5.52E1    6.554239e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 5.92E1    6.554239e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 6.31E1    6.554239e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 6.71E1    6.554239e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 7.10E1    6.554240e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 7.50E1    6.554240e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
# 7.89E1    6.554241e-09  1.323435e-07  1.463010e-04     0.821677     0.840306
#
#           S(6)(mol/kgw)   Ca(mol/kgw)    K(mol/kgw)   Mg(mol/kgw)  \
# Time (s)
# 4.34E1     2.190871e-07  4.250512e-08  1.708226e-08  1.502695e-07
# 4.74E1     1.152207e-01  2.157619e-02  9.059026e-03  7.969060e-02
# 5.13E1     1.152208e-01  2.157606e-02  9.059043e-03  7.969075e-02
# 5.52E1     1.152207e-01  2.157602e-02  9.059043e-03  7.969075e-02
# 5.92E1     1.152204e-01  2.157571e-02  9.059043e-03  7.969075e-02
# 6.31E1     1.152198e-01  2.157513e-02  9.059043e-03  7.969075e-02
# 6.71E1     1.152189e-01  2.157419e-02  9.059043e-03  7.969075e-02
# 7.10E1     1.152176e-01  2.157286e-02  9.059044e-03  7.969075e-02
# 7.50E1     1.152159e-01  2.157115e-02  9.059044e-03  7.969076e-02
# 7.89E1     1.152138e-01  2.156912e-02  9.059045e-03  7.969077e-02
#
#            Sr(mol/kgw)   Ba(mol/kgw)   Li(mol/kgw)  Zn(mol/kgw)  Ni(mol/kgw)  \
# Time (s)
# 4.34E1    2.101898e-10  1.777313e-13  7.288691e-11          NaN          NaN
# 4.74E1    1.114674e-04  9.425408e-08  3.865322e-05          NaN          NaN
# 5.13E1    1.114676e-04  9.425425e-08  3.865329e-05          NaN          NaN
# 5.52E1    1.114676e-04  9.425425e-08  3.865329e-05          NaN          NaN
# 5.92E1    1.114676e-04  9.425425e-08  3.865329e-05          NaN          NaN
# 6.31E1    1.114676e-04  9.425425e-08  3.865329e-05          NaN          NaN
# 6.71E1    1.114676e-04  9.425426e-08  3.865329e-05          NaN          NaN
# 7.10E1    1.114676e-04  9.425426e-08  3.865330e-05          NaN          NaN
# 7.50E1    1.114676e-04  9.425427e-08  3.865330e-05          NaN          NaN
# 7.89E1    1.114676e-04  9.425427e-08  3.865330e-05          NaN          NaN
#
#           Cu(mol/kgw)  Cd(mol/kgw)  Co(mol/kgw)  Pb(mol/kgw)
# Time (s)
# 4.34E1            NaN          NaN          NaN          NaN
# 4.74E1            NaN          NaN          NaN          NaN
# 5.13E1            NaN          NaN          NaN          NaN
# 5.52E1            NaN          NaN          NaN          NaN
# 5.92E1            NaN          NaN          NaN          NaN
# 6.31E1            NaN          NaN          NaN          NaN
# 6.71E1            NaN          NaN          NaN          NaN
# 7.10E1            NaN          NaN          NaN          NaN
# 7.50E1            NaN          NaN          NaN          NaN
# 7.89E1            NaN          NaN          NaN          NaN

# %% [markdown]
# ## Linear CF - Scaling

# %%
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200
final_cf = 1.117096

# execute the simulation
ross = ROSSPkg(database_selection, simulation, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective, final_cf)
ross.feed_geochemistry(water_selection)
ross.execute()
display(ross.processed_data)
# Out:
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 15:08:01.755218 local time.
# run_time (s): 6.117300800000066
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             9.85E-1
# 5.50E-1              8.15E0
# 6.35E-1              7.84E0
# 7.20E-1              7.53E0
# 8.04E-1              7.24E0
# 8.89E-1              6.95E0

# %% [markdown]
# ## Linear permeate - Brine

# %%
# %run ../../../rosspy/core.py
# import rosspy

# general parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75

# execute the simulation
ross = ROSSPkg(database_selection, simulation, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute()
display(ross.processed_data)
# Out:
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 6.64 seconds: 2022-01-21 15:06:50.262065 local time.
# run_time (s): 2.1555043999996997
#            Mn(mol/kgw)   Fe(mol/kgw)    B(mol/kgw)  Cl(mol/kgw)  Na(mol/kgw)  \
# Time (s)
# 4.34E1    1.236791e-14  2.497335e-13  2.760714e-10     0.000002     0.000002
# 4.74E1    6.556912e-09  1.323975e-07  1.463607e-04     0.822012     0.840649
# 5.13E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.52E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.92E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.31E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.71E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 7.10E1    6.556925e-09  1.323977e-07  1.463610e-04     0.822014     0.840651
# 7.50E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
# 7.89E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
#
#           S(6)(mol/kgw)   Ca(mol/kgw)    K(mol/kgw)   Mg(mol/kgw)  \
# Time (s)
# 4.34E1     2.192570e-07  4.254850e-08  1.709450e-08  1.503772e-07
# 4.74E1     1.152589e-01  2.157598e-02  9.062738e-03  7.972325e-02
# 5.13E1     1.152589e-01  2.157585e-02  9.062755e-03  7.972340e-02
# 5.52E1     1.152589e-01  2.157582e-02  9.062755e-03  7.972340e-02
# 5.92E1     1.152586e-01  2.157551e-02  9.062755e-03  7.972340e-02
# 6.31E1     1.152580e-01  2.157492e-02  9.062755e-03  7.972340e-02
# 6.71E1     1.152571e-01  2.157399e-02  9.062755e-03  7.972340e-02
# 7.10E1     1.152557e-01  2.157266e-02  9.062756e-03  7.972341e-02
# 7.50E1     1.152540e-01  2.157095e-02  9.062756e-03  7.972341e-02
# 7.89E1     1.152520e-01  2.156892e-02  9.062757e-03  7.972342e-02
#
#            Sr(mol/kgw)   Ba(mol/kgw)   Li(mol/kgw)  Zn(mol/kgw)  Ni(mol/kgw)  \
# Time (s)
# 4.34E1    2.103404e-10  1.778587e-13  7.293914e-11          NaN          NaN
# 4.74E1    1.115130e-04  9.429270e-08  3.866906e-05          NaN          NaN
# 5.13E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.52E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.92E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.31E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.71E1    1.115132e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.10E1    1.115133e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.50E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
# 7.89E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
#
#           Cu(mol/kgw)  Cd(mol/kgw)  Co(mol/kgw)  Pb(mol/kgw)
# Time (s)
# 4.34E1            NaN          NaN          NaN          NaN
# 4.74E1            NaN          NaN          NaN          NaN
# 5.13E1            NaN          NaN          NaN          NaN
# 5.52E1            NaN          NaN          NaN          NaN
# 5.92E1            NaN          NaN          NaN          NaN
# 6.31E1            NaN          NaN          NaN          NaN
# 6.71E1            NaN          NaN          NaN          NaN
# 7.10E1            NaN          NaN          NaN          NaN
# 7.50E1            NaN          NaN          NaN          NaN
# 7.89E1            NaN          NaN          NaN          NaN

# %% [markdown]
# ## Linear permeate - Scaling

# %%
# %run ../../../rosspy/core.py
# import rosspy

# initial parameters
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# execute the simulation
ross = ROSSPkg(database_selection, simulation, printing = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute()
display(ross.processed_data)
# Out:
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7.85 seconds: 2022-01-21 15:08:29.408801 local time.
# run_time (s): 6.10054080000009
# C:\Users\Andrew Freiburger\AppData\Roaming\Python\Python37\site-packages\sigfig\sigfig.py:572: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#              Gypsum (g/m^2)
# Distance (m)
# 1.27E-1              0.00E0
# 2.12E-1              0.00E0
# 2.96E-1              0.00E0
# 3.81E-1              0.00E0
# 4.66E-1             1.96E-2
# 5.50E-1              8.13E0
# 6.35E-1              8.00E0
# 7.20E-1              7.76E0
# 8.04E-1              7.51E0
# 8.89E-1              7.27E0
