# %% [markdown]
# # Comparison of precipitation from evaporation versus scaling from desalination

# %% [markdown]
# ## Evaporation

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
permeate_approach = 'linear_permeate'
simulation_perspective = 'all_distance'
simulation_type = 'evaporation'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation_type = simulation_type)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction(permeate_approach)
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# Estimated completion in 22.0 seconds by 2021-10-15 23:50:30.907793 local time.
#                              Gypsum
# Concentration Factor (CF)
# 1.00000                    0.000000
# 1.08578                    0.009480
# 1.10959                    0.017027
# 1.11571                    0.018918
# 1.11725                    0.019392
# 1.11763                    0.019510
# 1.11773                    0.019539
# 1.11775                    0.019547
# 1.11776                    0.019549

# %% [markdown]
# ## Desalination

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
ross = ROSSPkg(verbose = False)

# initial parameters
phreeqc_path = 'C:\\Program Files\\USGS\\phreeqc-3.6.2-15100-x64'
database_selection = 'pitzer'
simulation_title = 'test'
water_selection = 'red_sea'
permeate_approach = 'linear_permeate'
simulation_perspective = 'all_distance'
simulation_type = 'transport'
simulation_time = 200

# create the input file
ross.define_general(phreeqc_path, database_selection, simulation_title, simulation_type = simulation_type)
ross.transport(simulation_time, simulation_perspective, )
ross.reaction(permeate_approach)
ross.solutions(water_selection)
ross.equilibrium_phases()
ross.selected_output()
ross.export(print_block = False)

# execute and process the input file
raw_data = ross.execute(print_output = False)
scaling_data = ross.process_selected_output()
display(scaling_data)
# Out:
# Estimated completion in 38.0 seconds by 2021-10-15 23:50:41.035245 local time.
#              Gypsum
# Distance (m)
# 0.127 m        0.00
# 0.212 m        0.00
# 0.296 m        0.00
# 0.381 m        0.00
# 0.466 m       0.439
# 0.550 m        8.21
# 0.635 m        7.98
# 0.720 m        7.71
# 0.804 m        7.45
# 0.889 m        7.19
