# %% [markdown]
# # Single versus Dual domain

# %% [markdown]
# ## Single domain

# %% [markdown]
# ### Brine

# %%
# %run ../../../rosspy/core.py
# import rosspy

# general parameters
simulation_name = 'single_domain-brine'
database_selection = 'pitzer'
water_selection = 'red_sea'
simulation = 'brine'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross = ROSSPkg(database_selection, simulation)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177308071405103
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 6.64 seconds: 2022-01-21 14:53:58.511775 local time.
# run_time (s): 2.1603691999998773
#            Mn(mol/kgw)   Fe(mol/kgw)    B(mol/kgw)  Cl(mol/kgw)  Na(mol/kgw)  \
# Time (s)
# 4.34E1    1.236791e-14  2.497335e-13  2.760714e-10     0.000002     0.000002
# 4.74E1    6.556912e-09  1.323975e-07  1.463607e-04     0.822012     0.840649
# 5.13E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.52E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.92E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.31E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.71E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 7.10E1    6.556925e-09  1.323977e-07  1.463610e-04     0.822014     0.840651
# 7.50E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
# 7.89E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
#
#           S(6)(mol/kgw)   Ca(mol/kgw)    K(mol/kgw)   Mg(mol/kgw)  \
# Time (s)
# 4.34E1     2.192570e-07  4.254850e-08  1.709450e-08  1.503772e-07
# 4.74E1     1.152589e-01  2.157598e-02  9.062738e-03  7.972325e-02
# 5.13E1     1.152589e-01  2.157585e-02  9.062755e-03  7.972340e-02
# 5.52E1     1.152589e-01  2.157582e-02  9.062755e-03  7.972340e-02
# 5.92E1     1.152586e-01  2.157551e-02  9.062755e-03  7.972340e-02
# 6.31E1     1.152580e-01  2.157492e-02  9.062755e-03  7.972340e-02
# 6.71E1     1.152571e-01  2.157399e-02  9.062755e-03  7.972340e-02
# 7.10E1     1.152557e-01  2.157266e-02  9.062756e-03  7.972341e-02
# 7.50E1     1.152540e-01  2.157095e-02  9.062756e-03  7.972341e-02
# 7.89E1     1.152520e-01  2.156892e-02  9.062757e-03  7.972342e-02
#
#            Sr(mol/kgw)   Ba(mol/kgw)   Li(mol/kgw)  Zn(mol/kgw)  Ni(mol/kgw)  \
# Time (s)
# 4.34E1    2.103404e-10  1.778587e-13  7.293914e-11          NaN          NaN
# 4.74E1    1.115130e-04  9.429270e-08  3.866906e-05          NaN          NaN
# 5.13E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.52E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.92E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.31E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.71E1    1.115132e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.10E1    1.115133e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.50E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
# 7.89E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
#
#           Cu(mol/kgw)  Cd(mol/kgw)  Co(mol/kgw)  Pb(mol/kgw)
# Time (s)
# 4.34E1            NaN          NaN          NaN          NaN
# 4.74E1            NaN          NaN          NaN          NaN
# 5.13E1            NaN          NaN          NaN          NaN
# 5.52E1            NaN          NaN          NaN          NaN
# 5.92E1            NaN          NaN          NaN          NaN
# 6.31E1            NaN          NaN          NaN          NaN
# 6.71E1            NaN          NaN          NaN          NaN
# 7.10E1            NaN          NaN          NaN          NaN
# 7.50E1            NaN          NaN          NaN          NaN
# 7.89E1            NaN          NaN          NaN          NaN
#            Mn(mol/kgw)   Fe(mol/kgw)    B(mol/kgw)  Cl(mol/kgw)  Na(mol/kgw)  \
# Time (s)
# 4.34E1    1.236791e-14  2.497335e-13  2.760714e-10     0.000002     0.000002
# 4.74E1    6.556912e-09  1.323975e-07  1.463607e-04     0.822012     0.840649
# 5.13E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.52E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 5.92E1    6.556924e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.31E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 6.71E1    6.556925e-09  1.323977e-07  1.463609e-04     0.822014     0.840651
# 7.10E1    6.556925e-09  1.323977e-07  1.463610e-04     0.822014     0.840651
# 7.50E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
# 7.89E1    6.556926e-09  1.323978e-07  1.463610e-04     0.822014     0.840651
#
#           S(6)(mol/kgw)   Ca(mol/kgw)    K(mol/kgw)   Mg(mol/kgw)  \
# Time (s)
# 4.34E1     2.192570e-07  4.254850e-08  1.709450e-08  1.503772e-07
# 4.74E1     1.152589e-01  2.157598e-02  9.062738e-03  7.972325e-02
# 5.13E1     1.152589e-01  2.157585e-02  9.062755e-03  7.972340e-02
# 5.52E1     1.152589e-01  2.157582e-02  9.062755e-03  7.972340e-02
# 5.92E1     1.152586e-01  2.157551e-02  9.062755e-03  7.972340e-02
# 6.31E1     1.152580e-01  2.157492e-02  9.062755e-03  7.972340e-02
# 6.71E1     1.152571e-01  2.157399e-02  9.062755e-03  7.972340e-02
# 7.10E1     1.152557e-01  2.157266e-02  9.062756e-03  7.972341e-02
# 7.50E1     1.152540e-01  2.157095e-02  9.062756e-03  7.972341e-02
# 7.89E1     1.152520e-01  2.156892e-02  9.062757e-03  7.972342e-02
#
#            Sr(mol/kgw)   Ba(mol/kgw)   Li(mol/kgw)  Zn(mol/kgw)  Ni(mol/kgw)  \
# Time (s)
# 4.34E1    2.103404e-10  1.778587e-13  7.293914e-11          NaN          NaN
# 4.74E1    1.115130e-04  9.429270e-08  3.866906e-05          NaN          NaN
# 5.13E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.52E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 5.92E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.31E1    1.115132e-04  9.429287e-08  3.866913e-05          NaN          NaN
# 6.71E1    1.115132e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.10E1    1.115133e-04  9.429288e-08  3.866913e-05          NaN          NaN
# 7.50E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
# 7.89E1    1.115133e-04  9.429289e-08  3.866914e-05          NaN          NaN
#
#           Cu(mol/kgw)  Cd(mol/kgw)  Co(mol/kgw)  Pb(mol/kgw)
# Time (s)
# 4.34E1            NaN          NaN          NaN          NaN
# 4.74E1            NaN          NaN          NaN          NaN
# 5.13E1            NaN          NaN          NaN          NaN
# 5.52E1            NaN          NaN          NaN          NaN
# 5.92E1            NaN          NaN          NaN          NaN
# 6.31E1            NaN          NaN          NaN          NaN
# 6.71E1            NaN          NaN          NaN          NaN
# 7.10E1            NaN          NaN          NaN          NaN
# 7.50E1            NaN          NaN          NaN          NaN
# 7.89E1            NaN          NaN          NaN          NaN

# %% [markdown]
# ### Scaling

# %%
# %run ../../../rosspy/ro.py
# import rosspy

# initial parameters
simulation_name = 'single_domain-scaling'
database_selection = 'pitzer'
water_selection = 'red_sea'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross = ROSSPkg(database_selection, export_content = False)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-08 15:11:35.039435 local time.
# run_time (s): 7.737707300000004
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 0.013701135499988713,
#                                'H': 0.0006891522788491753,
#                                'O': 0.027347914980602753,
#                                'S': 0.01096179724055936}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 2.1578638453492665,
#                               'H': 0.10853821469541093,
#                               'O': 4.307166875502901,
#                               'S': 1.7264310644524232}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 2.1292656498084925,
#                                'H': 0.1070997564283633,
#                                'O': 4.250083941008283,
#                                'S': 1.7035506527548607}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 2.0772689306434504,
#                               'H': 0.10448437776100401,
#                               'O': 4.146296787381708,
#                               'S': 1.6619499042138386}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 2.025272211478408,
#                                'H': 0.1018689990936447,
#                                'O': 4.042509633755132,
#                                'S': 1.6203491556728162}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 1.973275492313365,
#                                'H': 0.0992536204262854,
#                                'O': 3.938722480128556,
#                                'S': 1.578748407131794}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 1.9212787731483225,
#                                'H': 0.0966382417589261,
#                                'O': 3.83493532650198,
#                                'S': 1.5371476585907717}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             0.000E0
# 1.27E-1             0.000E0
# 2.12E-1             0.000E0
# 2.96E-1             0.000E0
# 3.81E-1             0.000E0
# 4.66E-1            5.270E-2
# 5.50E-1             8.300E0
# 6.35E-1             8.190E0
# 7.20E-1             7.990E0
# 8.04E-1             7.790E0
# 8.89E-1             7.590E0
# 9.74E-1             7.390E0

# %% [markdown]
# ## Dual domain

# %% [markdown]
# ## Immobile phase

# %% [markdown]
# ### Brine

# %%
# %run ../../../rosspy/ro.py
# import rosspy

# general parameters
simulation_name = 'dual_domain-immobile-brine'
database_selection = 'pitzer'
water_selection = 'red_sea'
simulation = 'brine'
domain_phase = 'immobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross = ROSSPkg(database_selection, simulation, domain_phase = domain_phase)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177308071405103
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 6.64 seconds: 2022-01-21 14:55:04.277917 local time.
# run_time (s): 3.740912499999922
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-5d7854b642ab> in <module>
#      15 ross.reactive_transport(simulation_time, simulation_perspective)
#      16 ross.feed_geochemistry(water_selection)
# ---> 17 ross.execute(simulation_name)
#      18
#      19 # execute the input file
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in execute(self, simulation_name, selected_output_path, input_path, output_path, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots, scale_ions, selected_output_filename)
#     868         # conducting the appropriate visualization function
#     869         if self.parameters['simulation'] == 'brine':
# --> 870             self.processed_data = self._brine_plot(pyplot, title_font, label_font, export_format, x_label_number, export_name)
#     871         elif self.parameters['simulation'] == 'scaling':
#     872             self.processed_data = self._scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in _brine_plot(self, pyplot, title_font, label_font, export_format, x_label_number, export_name, log_scale)
#    1054             if len(time_serie) == 0:
#    1055                 error = f'\n\nThe {insufficient_elements} elements remain below the 1E-16 Molal threshold, and thus the figure could not be constructed.'
# -> 1056                 self._error(error)
#    1057
#    1058         # define the brine plot
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in _error(self, error)
#     967             output.write(error)
#     968             output.close()
# --> 969         raise IndexError(error)
#     970
#     971
#
# IndexError:
#
# The {'Na(mol/kgw)', 'Cl(mol/kgw)', 'K(mol/kgw)', 'B(mol/kgw)', 'Ca(mol/kgw)', 'Mg(mol/kgw)', 'Sr(mol/kgw)', 'Fe(mol/kgw)', 'Mn(mol/kgw)', 'Ba(mol/kgw)', 'Li(mol/kgw)', 'S(6)(mol/kgw)'} elements remain below the 1E-16 Molal threshold, and thus the figure could not be constructed.

# %% [markdown]
# ### Scaling

# %%
# %run ../../../rosspy/ro.py
# import rosspy

# initial parameters
simulation_name = 'dual_domain-immobile-scaling'
database_selection = 'pitzer'
water_selection = 'red_sea'
domain_phase = 'immobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross = ROSSPkg(database_selection, simulation, domain_phase = domain_phase)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-08 15:11:06.548830 local time.
# run_time (s): 14.041023599999995
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 0.162489747390758,
#                                 'H': 0.00817305833549781,
#                                 'O': 0.3243348550830497,
#                                 'S': 0.1300023391906945}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 0.05719639108154682,
#                                'H': 0.002876916534095229,
#                                'O': 0.1141658689892335,
#                                'S': 0.04576082339512447}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2            6.250E-1
# 1.27E-1            2.200E-1
# 2.12E-1             0.000E0
# 2.96E-1             0.000E0
# 3.81E-1             0.000E0
# 4.66E-1             0.000E0
# 5.50E-1             0.000E0
# 6.35E-1             0.000E0
# 7.20E-1             0.000E0
# 8.04E-1             0.000E0
# 8.89E-1             0.000E0
# 9.74E-1             0.000E0

# %% [markdown]
# ## Mobile phase

# %% [markdown]
# ### Brine

# %%
# run the ROSS model
# %run ../../../rosspy/core.py
# ross = ROSSPkg()
import rosspy
ross = rosspy.ROSSPkg(verbose = False)

# general parameters
simulation_name = 'dual_domain-mobile-brine'
database_selection = 'pitzer'
water_selection = 'red_sea'
simulation = 'brine'
domain_phase = 'mobile'
simulation_perspective = 'all_time'
simulation_time = 75

# create the input file
ross = ROSSPkg(database_selection, simulation, domain_phase = domain_phase)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177308071405103
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 6.64 seconds: 2022-01-21 14:55:24.198055 local time.
# run_time (s): 3.7192978000000494
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-a8f4ee6d5203> in <module>
#      18 ross.reactive_transport(simulation_time, simulation_perspective)
#      19 ross.feed_geochemistry(water_selection)
# ---> 20 ross.execute(simulation_name)
#      21
#      22 # execute the input file
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in execute(self, simulation_name, selected_output_path, input_path, output_path, plot_title, title_font, label_font, x_label_number, export_name, export_format, individual_plots, scale_ions, selected_output_filename)
#     868         # conducting the appropriate visualization function
#     869         if self.parameters['simulation'] == 'brine':
# --> 870             self.processed_data = self._brine_plot(pyplot, title_font, label_font, export_format, x_label_number, export_name)
#     871         elif self.parameters['simulation'] == 'scaling':
#     872             self.processed_data = self._scaling_plot(title_font, label_font, individual_plots, x_label_number, export_name, export_format)
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in _brine_plot(self, pyplot, title_font, label_font, export_format, x_label_number, export_name, log_scale)
#    1054             if len(time_serie) == 0:
#    1055                 error = f'\n\nThe {insufficient_elements} elements remain below the 1E-16 Molal threshold, and thus the figure could not be constructed.'
# -> 1056                 self._error(error)
#    1057
#    1058         # define the brine plot
#
# ~\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\PHREEQC\ROSS\rosspy\core.py in _error(self, error)
#     967             output.write(error)
#     968             output.close()
# --> 969         raise IndexError(error)
#     970
#     971
#
# IndexError:
#
# The {'Na(mol/kgw)', 'Cl(mol/kgw)', 'K(mol/kgw)', 'B(mol/kgw)', 'Ca(mol/kgw)', 'Mg(mol/kgw)', 'Sr(mol/kgw)', 'Fe(mol/kgw)', 'Mn(mol/kgw)', 'Ba(mol/kgw)', 'Li(mol/kgw)', 'S(6)(mol/kgw)'} elements remain below the 1E-16 Molal threshold, and thus the figure could not be constructed.

# %% [markdown]
# ### Scaling

# %%
# %run ../../../rosspy/ro.py
# import rosspy

# initial parameters
simulation_name = 'dual_domain-mobile-scaling'
database_selection = 'pitzer'
water_selection = 'red_sea'
domain_phase = 'mobile'
simulation = 'scaling'
simulation_perspective = 'all_distance'
simulation_time = 200

# create the input file
ross = ROSSPkg(database_selection, simulation, domain_phase = domain_phase)
ross.reactive_transport(simulation_time, simulation_perspective)
ross.feed_geochemistry(water_selection)
ross.execute(simulation_name)

# execute the input file
display(ross.processed_data)
# Out:
# Effluent module 1 CF: 1.1177571260302372
#
# --> The ['Zn', 'Ni', 'Cu', 'Cd', 'Co', 'Pb'] elements are not accepted by the pitzer database
#
# Estimated completion in 7 seconds: 2022-04-08 15:11:20.803354 local time.
# run_time (s): 14.010318000000005
# mineral Gypsum   {'formula': 'CaSO4:2H2O', 'mass': '170'}
# ionic masses
#  ==============
# {'0.0423 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.127 (m)': {'ion (g/m^2)': {'Ca': 0.00035357769032228945,
#                                'H': 1.7784574938043237e-05,
#                                'O': 0.0007057526446607162,
#                                'S': 0.00028288509007895127}},
#  '0.212 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.296 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.381 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.466 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.55 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.635 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.72 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.804 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.889 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}},
#  '0.974 (m)': {'ion (g/m^2)': {'Ca': 0.0, 'H': 0.0, 'O': 0.0, 'S': 0.0}}}
#              Gypsum (g/m^2)
# Distance (m)
# 4.23E-2             0.000E0
# 1.27E-1            1.360E-3
# 2.12E-1             0.000E0
# 2.96E-1             0.000E0
# 3.81E-1             0.000E0
# 4.66E-1             0.000E0
# 5.50E-1             0.000E0
# 6.35E-1             0.000E0
# 7.20E-1             0.000E0
# 8.04E-1             0.000E0
# 8.89E-1             0.000E0
# 9.74E-1             0.000E0
